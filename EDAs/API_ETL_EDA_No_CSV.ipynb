# %% [markdown]
# # API EDA
# - API Link:https://site.financialmodelingprep.com/
# - API Documentation: https://site.financialmodelingprep.com/developer/docs

# %% [markdown]
# ## Things to consider about the process carried out in this notebook!
# - This EDA is the version of the original EDA without the data extraction process from a CSV, but directly all taken from the API. Something to keep in mind is that this EDA has more data from the beginning since there were no limitations when handling and saving the data provided by the entire extraction process in a CSV.
#
# - There is another EDA that was worked with a CSV in another notebook, which is obtained at the end of the entire extraction process, so that the process of extracting more than 50,000 queries did not have to be repeated every time in that notebook was worked on. Of course, here you will find the complete extraction process as a result of a dataframe.
#
# - The process carried out was first a query to the financialmodelng API in which we obtained a dataset with 6 fields with very general information. Therefore, we decided to complement this dataset with information from Yahoo Finance, being able to obtain high-value information with which to complement the dataset obtained from the API extraction, which was very limited. This additional process added significant value to the dataset with new fields and a lot of records.
#
# - Let's remember that this data extraction process thanks to an API is done in order to add value to our learning that we obtained by analyzing our first dataset of tech layoffs. That's why we decided to approach information related to the financial market of companies and their sectors.

# %% [markdown]
# ## Library Imports
# - Requests: This library facilitates all the work of sending information requests to APIs, allowing us to access the information in this dataset.
# - Pandas, Matplotlib, and Numpy: These libraries will help us throughout the process of analysis and deep cleaning of our data.
# - Yfinance: This library helps us to access vital financial data in a simple and fast way, without having as many limitations as APIs can have for their queries.

# %%
import requests
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Initial API Extraction Process (Option for direct data extraction in this EDA)
# - The code makes a query to the fields that, as a first layer, the API allows us to request without any limitation on the number of queries, thus obtaining a general list of available stocks for each company that the API has registered.
#
# - As a second step, the code will seek to complement the dataset obtained with fields that the same API offers us but in a limited way per query. That's why we use the yfinance library as a powerful tool for financial analysts.

# %%
# Paso 1: Obtener la lista de acciones disponibles
api_url = "https://financialmodelingprep.com/api/v3/available-traded/list?apikey=7lZIU82kV1JVXJZP2zHFFlJLvdvsswj0"
response = requests.get(api_url)

if response.status_code == 200:
    stock_data = response.json()
    df = pd.DataFrame(stock_data)
    df = df[['symbol', 'name', 'price', 'exchange', 'exchangeShortName']]
else:
    print("Error en la solicitud:", response.status_code)
    raise Exception("No se pudo obtener los datos de la API.")

# Definir la función para obtener información financiera
def get_financial_info(symbol, index, total):
    try:
        ticker = yf.Ticker(symbol)
        info = ticker.info
        print(f"Procesando {index + 1}/{total}: {symbol}")
        return {
            'Industry': info.get('industry', 'Industria no disponible'),
            'Profit Margins': info.get('profitMargins', 'No disponible'),
            'PE Ratio': info.get('trailingPE', 'No disponible'),
            'Country': info.get('country', 'País no disponible'),
            'Full Time Employees': info.get('fullTimeEmployees', 'No disponible'),
            'City': info.get('city', 'Ciudad no disponible')
        }
    except Exception as e:
        print(f"Error al obtener la información de {symbol}: {e}")
        return {
            'Industry': 'Error',
            'Profit Margins': 'Error',
            'PE Ratio': 'Error',
            'Country': 'Error',
            'Full Time Employees': 'Error',
            'City': 'Error'
        }
    
    
# Paso 2: Obtener información financiera adicional para cada acción
info_list = []
total_symbols = len(df)
for index, symbol in enumerate(df['symbol']):
    info = get_financial_info(symbol, index, total_symbols)
    info_list.append(info)

df_info = pd.DataFrame(info_list)

# Combinar los DataFrames
df_final = pd.concat([df, df_info], axis=1)

# Mostrar el resultado
print(df_final.head())
# Out:
# Procesando 1/57525: NDBKY
# Procesando 2/57525: NRRWF
# Procesando 3/57525: 5309.KL
# Procesando 4/57525: TQGEX
# Procesando 5/57525: MEA.AX
# Procesando 6/57525: BNP.PA
# Procesando 7/57525: SLQT
# Procesando 8/57525: 0298.HK
# Procesando 9/57525: RAFL.BO
# Procesando 10/57525: ANDE
# Procesando 11/57525: KITL
# Procesando 12/57525: BYOT.L
# Procesando 13/57525: 001065.KS
# Procesando 14/57525: JVTNX
# Procesando 15/57525: VSL.NZ
# Procesando 16/57525: 7076.KL
# Procesando 17/57525: 0613.HK
# Procesando 18/57525: 002732.SZ
# Procesando 19/57525: GOVB
# Procesando 20/57525: RYRIX
# Procesando 21/57525: 000972.SZ
# Procesando 22/57525: SWELECTES.NS
# Procesando 23/57525: NGY.AX
# Procesando 24/57525: SHUKJEW.BO
# Procesando 25/57525: ERG.WA
# Procesando 26/57525: 036530.KS
# Procesando 27/57525: SSR.AX
# Procesando 28/57525: ISOLF
# Procesando 29/57525: 2445.KL
# Procesando 30/57525: KCEA.SG
# Procesando 31/57525: EOS
# Procesando 32/57525: 3245.T
# Procesando 33/57525: RAS.AX
# Procesando 34/57525: 348370.KQ
# Procesando 35/57525: MHK.AX
# Procesando 36/57525: 090435.KS
# Procesando 37/57525: STX.AX
# Procesando 38/57525: DVSPF
# Procesando 39/57525: JAPAY
# Procesando 40/57525: AFI.NZ
# Procesando 41/57525: 605298.SS
# Procesando 42/57525: USM.NZ
# Procesando 43/57525: CSPCY
# Procesando 44/57525: ALPHI.PA
# Procesando 45/57525: 8354.T
# Procesando 46/57525: BXP.L
# Procesando 47/57525: AEIN.DE
# Procesando 48/57525: VITROA.MX
# Procesando 49/57525: 1417.T
# Procesando 50/57525: 688283.SS
# Procesando 51/57525: 1MC.AX
# Procesando 52/57525: APN.WA
# Procesando 53/57525: JLVMX
# Procesando 54/57525: JMAS.JK
# Procesando 55/57525: 002244.SZ
# Procesando 56/57525: 1986.HK
# Procesando 57/57525: RCEL
# Procesando 58/57525: 000663.SZ
# Procesando 59/57525: ASIA
# Procesando 60/57525: UT8.DE
# Procesando 61/57525: 605258.SS
# Procesando 62/57525: MEM.AX
# Procesando 63/57525: 33626K.KS
# Procesando 64/57525: 7609.T
# Procesando 65/57525: 6638.T
# Procesando 66/57525: AINO.ST
# Procesando 67/57525: MGA.AX
# Procesando 68/57525: DECB.BR
# Procesando 69/57525: ASAHIINDIA.BO
# Procesando 70/57525: EQUITASBNK.NS
# Procesando 71/57525: 1980.HK
# Procesando 72/57525: TRZ.TO
# Procesando 73/57525: DOG
# Procesando 74/57525: 8362.HK
# Procesando 75/57525: ATN.L
# Procesando 76/57525: 002823.SZ
# Procesando 77/57525: MNP.L
# Procesando 78/57525: FRHC
# Procesando 79/57525: RYTM
# Procesando 80/57525: 688787.SS
# Procesando 81/57525: 8203.HK
# Procesando 82/57525: RSGK.JK
# Procesando 83/57525: 002381.SZ
# Procesando 84/57525: PCK
# Procesando 85/57525: 0672.HK
# Procesando 86/57525: 8066.HK
# Procesando 87/57525: TNRG
# Procesando 88/57525: 0200.KL
# Procesando 89/57525: 2135.HK
# Procesando 90/57525: PORT.JK
# Procesando 91/57525: 1143.HK
# Procesando 92/57525: 3104.T
# Procesando 93/57525: 0162.HK
# Procesando 94/57525: 300719.SZ
# Procesando 95/57525: SYVKUA.CO
# Procesando 96/57525: DHL.DE
# Procesando 97/57525: NXS.AX
# Procesando 98/57525: JMFINANCIL.NS
# Procesando 99/57525: 603648.SS
# Procesando 100/57525: 150A.T
# Procesando 101/57525: AOX.DE
# Procesando 102/57525: 00806K.KS
# Procesando 103/57525: 2199.HK
# Procesando 104/57525: ISFU.L
# Procesando 105/57525: FKWL
# Procesando 106/57525: INS.DE
# Procesando 107/57525: 3255.KL
# Procesando 108/57525: MTEM
# Procesando 109/57525: SOLTEQ.HE
# Procesando 110/57525: NPR.AX
# Procesando 111/57525: 2427.TW
# Procesando 112/57525: 8065.HK
# Procesando 113/57525: MONGIPA.BO
# Procesando 114/57525: PAIAX
# Procesando 115/57525: VATN.SW
# Procesando 116/57525: SDE.TO
# Procesando 117/57525: NIRAVCOM.BO
# Procesando 118/57525: LLY.SW
# Procesando 119/57525: 1260.HK
# Procesando 120/57525: BCDS
# Procesando 121/57525: 094170.KQ
# Procesando 122/57525: PNBN.JK
# Procesando 123/57525: 000407.SZ
# Procesando 124/57525: BNY
# Procesando 125/57525: 1960.HK
# Procesando 126/57525: 600567.SS
# Procesando 127/57525: SHECF
# Procesando 128/57525: LU0496786657.SG
# Procesando 129/57525: 0306.HK
# Procesando 130/57525: 031440.KS
# Procesando 131/57525: RCKY
# Procesando 132/57525: 6395.T
# Procesando 133/57525: GLTL.L
# Procesando 134/57525: 319870.KS
# Procesando 135/57525: OMV.VI
# Procesando 136/57525: 300051.SZ
# Procesando 137/57525: BORORENEW.NS
# Procesando 138/57525: NICE.TA
# Procesando 139/57525: UBVRX
# Procesando 140/57525: BFIN.JK
# Procesando 141/57525: 4420.T
# Procesando 142/57525: GAP.AX
# Procesando 143/57525: 600027.SS
# Procesando 144/57525: ASUR
# Procesando 145/57525: ACT.DE
# Procesando 146/57525: ASTEC.NS
# Procesando 147/57525: 2326.T
# Procesando 148/57525: JDPAX
# Procesando 149/57525: ARTH
# Procesando 150/57525: NARI
# Procesando 151/57525: 688356.SS
# Procesando 152/57525: JIGZX
# Procesando 153/57525: 4461.T
# Procesando 154/57525: ALEAC.PA
# Procesando 155/57525: SOP.AX
# Procesando 156/57525: WRT1V.HE
# Procesando 157/57525: 3320.HK
# Procesando 158/57525: BTE.SI
# Procesando 159/57525: YASKY
# Procesando 160/57525: NITINSPIN.NS
# Procesando 161/57525: 3828.HK
# Procesando 162/57525: KRKNF
# Procesando 163/57525: 9900.HK
# Procesando 164/57525: 316140.KS
# Procesando 165/57525: NTAR.CN
# Procesando 166/57525: 688233.SS
# Procesando 167/57525: RYAM
# Procesando 168/57525: 6272.T
# Procesando 169/57525: RAK.NZ
# Procesando 170/57525: 2325.HK
# Procesando 171/57525: ZUR.TA
# Procesando 172/57525: ETBB.DE
# Procesando 173/57525: 603259.SS
# Procesando 174/57525: 220100.KQ
# Procesando 175/57525: KTA.DE
# Procesando 176/57525: 3638.HK
# Procesando 177/57525: 1999.HK
# Procesando 178/57525: WBE.AX
# Procesando 179/57525: 1977.HK
# Procesando 180/57525: 000822.SZ
# Procesando 181/57525: 0R1D.L
# Procesando 182/57525: CREATIVE.BO
# Procesando 183/57525: 2393.HK
# Procesando 184/57525: 7931.T
# Procesando 185/57525: SOFO
# Procesando 186/57525: 8129.T
# Procesando 187/57525: EMAUF
# Procesando 188/57525: GRPLTD.BO
# Procesando 189/57525: 8422.HK
# Procesando 190/57525: 0N9V.L
# Procesando 191/57525: ENW.L
# Procesando 192/57525: GCEH
# Procesando 193/57525: 0M6I.L
# Procesando 194/57525: Q01.SI
# Procesando 195/57525: 002787.SZ
# Procesando 196/57525: 002302.SZ
# Procesando 197/57525: 1797.HK
# Procesando 198/57525: 4098.T
# Procesando 199/57525: 6493.T
# Procesando 200/57525: XANO-B.ST
# Procesando 201/57525: 2198.HK
# Procesando 202/57525: ZLD.AX
# Procesando 203/57525: KNCRY
# Procesando 204/57525: MIT.BK
# Procesando 205/57525: GMTD.JK
# Procesando 206/57525: 002790.SZ
# Procesando 207/57525: BBIL.L
# Procesando 208/57525: 0L7S.L
# Procesando 209/57525: MOWI.OL
# Procesando 210/57525: ENSG
# Procesando 211/57525: SBIO.L
# Procesando 212/57525: 002347.SZ
# Procesando 213/57525: FEV.DE
# Procesando 214/57525: PSDN.JK
# Procesando 215/57525: IUSA.DE
# Procesando 216/57525: POLYPLEX.BO
# Procesando 217/57525: TIPRX
# Procesando 218/57525: POL.AX
# Procesando 219/57525: SIMBHALS.BO
# Procesando 220/57525: FEXD
# Procesando 221/57525: JUBLINGREA.BO
# Procesando 222/57525: 2558.HK
# Procesando 223/57525: 002554.SZ
# Procesando 224/57525: NOCT
# Procesando 225/57525: 8471.HK
# Procesando 226/57525: 8801.T
# Procesando 227/57525: DNA.AX
# Procesando 228/57525: DLAKF
# Procesando 229/57525: 009810.KS
# Procesando 230/57525: BCI.SN
# Procesando 231/57525: SAMF.JK
# Procesando 232/57525: ALLIX.PA
# Procesando 233/57525: MON100.NS
# Procesando 234/57525: NNTL.BO
# Procesando 235/57525: MDZ.L
# Procesando 236/57525: JACRX
# Procesando 237/57525: 001210.KS
# Procesando 238/57525: 086280.KS
# Procesando 239/57525: 4448.T
# Procesando 240/57525: 002327.SZ
# Procesando 241/57525: 688328.SS
# Procesando 242/57525: STI
# Procesando 243/57525: ECHO.L
# Procesando 244/57525: 688326.SS
# Procesando 245/57525: FORTY
# Procesando 246/57525: TAPP
# Procesando 247/57525: 000532.SZ
# Procesando 248/57525: 4099.T
# Procesando 249/57525: 600894.SS
# Procesando 250/57525: 2157.T
# Procesando 251/57525: 9926.TW
# Procesando 252/57525: 0025.HK
# Procesando 253/57525: 0375.HK
# Procesando 254/57525: 273640.KQ
# Procesando 255/57525: 015860.KS
# Procesando 256/57525: DRTSW
# Procesando 257/57525: 000999.SZ
# Procesando 258/57525: DEMG.L
# Procesando 259/57525: 3202.T
# Procesando 260/57525: 4597.T
# Procesando 261/57525: 603656.SS
# Procesando 262/57525: MSUMI.BO
# Procesando 263/57525: 1903.HK
# Procesando 264/57525: DSCF
# Procesando 265/57525: 7438.T
# Procesando 266/57525: 002117.SZ
# Procesando 267/57525: SANION.ST
# Procesando 268/57525: AEI.AX
# Procesando 269/57525: ICRA.BO
# Procesando 270/57525: ACHFF
# Procesando 271/57525: 371470.KS
# Procesando 272/57525: 26ID.PA
# Procesando 273/57525: 8163.T
# Procesando 274/57525: YPF
# Procesando 275/57525: 8112.TW
# Procesando 276/57525: ZUP.TO
# Procesando 277/57525: DEI
# Procesando 278/57525: RICOAUTO.NS
# Procesando 279/57525: FFI.AX
# Procesando 280/57525: DSVSF
# Procesando 281/57525: SIV.AX
# Procesando 282/57525: WESNX
# Procesando 283/57525: RAI.L
# Procesando 284/57525: SANSERA.NS
# Procesando 285/57525: GDMA
# Procesando 286/57525: IQQ0.DE
# Procesando 287/57525: 000050.SZ
# Procesando 288/57525: FLUX
# Procesando 289/57525: 600326.SS
# Procesando 290/57525: SEMAC.BO
# Procesando 291/57525: LHKG.DE
# Procesando 292/57525: 1651.HK
# Procesando 293/57525: 603005.SS
# Procesando 294/57525: SBMO.AS
# Procesando 295/57525: 003010.KS
# Procesando 296/57525: 1351.HK
# Procesando 297/57525: PNN.AX
# Procesando 298/57525: EXN.PA
# Procesando 299/57525: 6978.HK
# Procesando 300/57525: SES.WA
# Procesando 301/57525: 000156.SZ
# Procesando 302/57525: EESE
# Procesando 303/57525: WDC
# Procesando 304/57525: 3321.T
# Procesando 305/57525: UNIT
# Procesando 306/57525: HTB.TO
# Procesando 307/57525: LLC.AX
# Procesando 308/57525: 7739.T
# Procesando 309/57525: XLF
# Procesando 310/57525: FLN.AX
# Procesando 311/57525: FCVH.TO
# Procesando 312/57525: TMG.AX
# Procesando 313/57525: 377300.KS
# Procesando 314/57525: ONE.V
# Procesando 315/57525: HLIO
# Procesando 316/57525: AMSYF
# Procesando 317/57525: VNA.DE
# Procesando 318/57525: 0733.HK
# Procesando 319/57525: RIE.AX
# Procesando 320/57525: ALNT.MC
# Procesando 321/57525: 0P0001LJIZ.F
# Procesando 322/57525: BCOW
# Procesando 323/57525: ZION
# Procesando 324/57525: CWEU.L
# Procesando 325/57525: 002076.SZ
# Procesando 326/57525: 8480.HK
# Procesando 327/57525: PTBL.TA
# Procesando 328/57525: VMI
# Procesando 329/57525: BIRD.JK
# Procesando 330/57525: TEF
# Procesando 331/57525: 8509.HK
# Procesando 332/57525: 0083.HK
# Procesando 333/57525: 2005.HK
# Procesando 334/57525: 002061.SZ
# Procesando 335/57525: 001060.KS
# Procesando 336/57525: VAPU.L
# Procesando 337/57525: IRVRF
# Procesando 338/57525: 078930.KS
# Procesando 339/57525: IHYU.MI
# Procesando 340/57525: MSJA.JK
# Procesando 341/57525: TECHNOPACK.BO
# Procesando 342/57525: NIMBSPROJ.BO
# Procesando 343/57525: BKCC.TO
# Procesando 344/57525: MCN
# Procesando 345/57525: KPO.AX
# Procesando 346/57525: 0JW9.L
# Procesando 347/57525: TEL
# Procesando 348/57525: NDSN
# Procesando 349/57525: PBF.WA
# Procesando 350/57525: 1397.HK
# Procesando 351/57525: 379780.KS
# Procesando 352/57525: LUNR
# Procesando 353/57525: PGHH.BO
# Procesando 354/57525: 0P000147MD.L
# Procesando 355/57525: MPA.AX
# Procesando 356/57525: HDW-B.ST
# Procesando 357/57525: 1108.HK
# Procesando 358/57525: OPHLY
# Procesando 359/57525: IHG.L
# Procesando 360/57525: 7701.T
# Procesando 361/57525: 0P00011WUD.L
# Procesando 362/57525: 0092.HK
# Procesando 363/57525: DMCHY
# Procesando 364/57525: BPFG.F
# Procesando 365/57525: 0KXA.L
# Procesando 366/57525: INAI.JK
# Procesando 367/57525: 688098.SS
# Procesando 368/57525: 300542.SZ
# Procesando 369/57525: NCC-A.ST
# Procesando 370/57525: AHX.AX
# Procesando 371/57525: SXNTF
# Procesando 372/57525: 1165.HK
# Procesando 373/57525: 301020.SZ
# Procesando 374/57525: 1202.HK
# Procesando 375/57525: AXI.AX
# Procesando 376/57525: 0P00011HBK.F
# Procesando 377/57525: NAAS
# Procesando 378/57525: 2208.TW
# Procesando 379/57525: EMQP.L
# Procesando 380/57525: M2M.AX
# Procesando 381/57525: 144510.KQ
# Procesando 382/57525: ONEV
# Procesando 383/57525: HGLD
# Procesando 384/57525: 6167.T
# Procesando 385/57525: FG1.AX
# Procesando 386/57525: PCIEX
# Procesando 387/57525: VAR.AX
# Procesando 388/57525: MTRN.TA
# Procesando 389/57525: SWAT.JK
# Procesando 390/57525: IDTM.L
# Procesando 391/57525: JGH.AX
# Procesando 392/57525: CINT.ST
# Procesando 393/57525: HROWL
# Procesando 394/57525: 300468.SZ
# Procesando 395/57525: 600238.SS
# Procesando 396/57525: 7537.T
# Procesando 397/57525: 9743.T
# Procesando 398/57525: FUND
# Procesando 399/57525: CGSHY
# Procesando 400/57525: SEMB.L
# Procesando 401/57525: KIMIABL.BO
# Procesando 402/57525: REVO.V
# Procesando 403/57525: TNDM
# Procesando 404/57525: 002159.SZ
# Procesando 405/57525: 0VQD.L
# Procesando 406/57525: 2972.T
# Procesando 407/57525: NICO.CN
# Procesando 408/57525: 000719.SZ
# Procesando 409/57525: CRESW
# Procesando 410/57525: 1379.HK
# Procesando 411/57525: MANN.CN
# Procesando 412/57525: ESVIF
# Procesando 413/57525: FBSE
# Procesando 414/57525: AGR.VI
# Procesando 415/57525: SHIVALIK.NS
# Procesando 416/57525: OMVJF
# Procesando 417/57525: 000651.SZ
# Procesando 418/57525: ATP.WA
# Procesando 419/57525: ROG.AX
# Procesando 420/57525: EMXF
# Procesando 421/57525: RWDYX
# Procesando 422/57525: YNVYF
# Procesando 423/57525: BFH
# Procesando 424/57525: FHN
# Procesando 425/57525: 9983.T
# Procesando 426/57525: SCMIX
# Procesando 427/57525: QZMRF
# Procesando 428/57525: 0095.HK
# Procesando 429/57525: PSCSX
# Procesando 430/57525: DRDR.L
# Procesando 431/57525: QBCRF
# Procesando 432/57525: CPSS
# Procesando 433/57525: 008730.KS
# Procesando 434/57525: 8025.T
# Procesando 435/57525: UVRBF
# Procesando 436/57525: CPAI
# Procesando 437/57525: MIKP
# Procesando 438/57525: AGR.L
# Procesando 439/57525: JENIX
# Procesando 440/57525: 300693.SZ
# Procesando 441/57525: VIAO
# Procesando 442/57525: KBHL.CO
# Procesando 443/57525: CBCYB
# Procesando 444/57525: SNG.MC
# Procesando 445/57525: 6787.T
# Procesando 446/57525: PRX.AX
# Procesando 447/57525: ODOT
# Procesando 448/57525: 4828.T
# Procesando 449/57525: FDR.AX
# Procesando 450/57525: 300301.SZ
# Procesando 451/57525: F
# Procesando 452/57525: BTBFX
# Procesando 453/57525: DOLE
# Procesando 454/57525: VLEOX
# Procesando 455/57525: 300877.SZ
# Procesando 456/57525: 111770.KS
# Procesando 457/57525: ALCKX
# Procesando 458/57525: 2053.T
# Procesando 459/57525: DBB
# Procesando 460/57525: RONY.JK
# Procesando 461/57525: TF.TO
# Procesando 462/57525: UGIC
# Procesando 463/57525: AZEV4.SA
# Procesando 464/57525: LISOX
# Procesando 465/57525: 600036.SS
# Procesando 466/57525: PPL-PQ.TO
# Procesando 467/57525: HRTX
# Procesando 468/57525: HBLRX
# Procesando 469/57525: BCONCEPTS.BO
# Procesando 470/57525: FIVLX
# Procesando 471/57525: BNK.PA
# Procesando 472/57525: FWFW
# Procesando 473/57525: MCEMX
# Procesando 474/57525: CHSCM
# Procesando 475/57525: RTX.CO
# Procesando 476/57525: CAFRX
# Procesando 477/57525: WIHL.ST
# Procesando 478/57525: AQMIX
# Procesando 479/57525: SZG.DE
# Procesando 480/57525: 002374.SZ
# Procesando 481/57525: DOHL4.SA
# Procesando 482/57525: SSIFX
# Procesando 483/57525: RANJY
# Procesando 484/57525: SNDL
# Procesando 485/57525: HICN.TA
# Procesando 486/57525: 002356.SZ
# Procesando 487/57525: PPPM.BK
# Procesando 488/57525: TEQAX
# Procesando 489/57525: SVSE
# Procesando 490/57525: AMNI.ST
# Procesando 491/57525: 1417.HK
# Procesando 492/57525: BACAX
# Procesando 493/57525: ARTO.JK
# Procesando 494/57525: CNT.BK
# Procesando 495/57525: WMVG.L
# Procesando 496/57525: RPSGVENT.BO
# Procesando 497/57525: DEO
# Procesando 498/57525: MASGX
# Procesando 499/57525: JWEL
# Procesando 500/57525: CWBU.SI
# Procesando 501/57525: EXXW.DE
# Procesando 502/57525: FRFZX
# Procesando 503/57525: TIKK
# Procesando 504/57525: CCRO3.SA
# Procesando 505/57525: RRTIX
# Procesando 506/57525: EAERX
# Procesando 507/57525: ICAGY
# Procesando 508/57525: RCIAF
# Procesando 509/57525: MISVF
# Procesando 510/57525: SSRM
# Procesando 511/57525: GNLN
# Procesando 512/57525: B3SA3.SA
# Procesando 513/57525: NYMTZ
# Procesando 514/57525: WDGJY
# Procesando 515/57525: RHIM.VI
# Procesando 516/57525: VIXY
# Procesando 517/57525: 603043.SS
# Procesando 518/57525: 4462.T
# Procesando 519/57525: UEPEO
# Procesando 520/57525: 3476.KL
# Procesando 521/57525: FMCCO
# Procesando 522/57525: DENORA.BO
# Procesando 523/57525: MM1.AX
# Procesando 524/57525: SOUTHBANK.BO
# Procesando 525/57525: 5IG.SI
# Procesando 526/57525: 2376.HK
# Procesando 527/57525: 9951.TWO
# Procesando 528/57525: LWSCF
# Procesando 529/57525: NXMH
# Procesando 530/57525: 1852.T
# Procesando 531/57525: CHR
# Procesando 532/57525: 002478.SZ
# Procesando 533/57525: EMBR3.SA
# Procesando 534/57525: VIS.V
# Procesando 535/57525: ARWYF
# Procesando 536/57525: BNBR3.SA
# Procesando 537/57525: KLBN11.SA
# Procesando 538/57525: LPP.WA
# Procesando 539/57525: 1898.HK
# Procesando 540/57525: 600073.SS
# Procesando 541/57525: 020150.KS
# Procesando 542/57525: HDIUF
# Procesando 543/57525: EAATF
# Procesando 544/57525: 001550.KS
# Procesando 545/57525: JCK.BK
# Procesando 546/57525: IGTI11.SA
# Procesando 547/57525: HP3A.DE
# Procesando 548/57525: BDYS
# Procesando 549/57525: PREMCO.BO
# Procesando 550/57525: 601728.SS
# Procesando 551/57525: 002946.SZ
# Procesando 552/57525: 9508.T
# Procesando 553/57525: MYPK3.SA
# Procesando 554/57525: AIRARABIA.AE
# Procesando 555/57525: BNS.TO
# Procesando 556/57525: DOU.AX
# Procesando 557/57525: 2514.TW
# Procesando 558/57525: 0J1G.L
# Procesando 559/57525: GNS
# Procesando 560/57525: UIMC.DE
# Procesando 561/57525: ARSLF
# Procesando 562/57525: BW
# Procesando 563/57525: GOTU
# Procesando 564/57525: WLN.PA
# Procesando 565/57525: 000030.SZ
# Procesando 566/57525: UDR
# Procesando 567/57525: NECCLTD.BO
# Procesando 568/57525: 603396.SS
# Procesando 569/57525: 600801.SS
# Procesando 570/57525: CBAV3.SA
# Procesando 571/57525: PNCINFRA.NS
# Procesando 572/57525: RBMNF
# Procesando 573/57525: SANB11.SA
# Procesando 574/57525: PES.DE
# Procesando 575/57525: GRLRF
# Procesando 576/57525: 2128.HK
# Procesando 577/57525: KMSWF
# Procesando 578/57525: 0089.HK
# Procesando 579/57525: UNLYF
# Procesando 580/57525: 8120.HK
# Procesando 581/57525: POS.L
# Procesando 582/57525: 7779.T
# Procesando 583/57525: MGEE
# Procesando 584/57525: FXG
# Procesando 585/57525: SMTO3.SA
# Procesando 586/57525: CLCGY
# Procesando 587/57525: GOKUL.BO
# Procesando 588/57525: 00088K.KS
# Procesando 589/57525: RIGH
# Procesando 590/57525: ESLA
# Procesando 591/57525: 0331.HK
# Procesando 592/57525: 3309.HK
# Procesando 593/57525: UOVEF
# Procesando 594/57525: XPPLF
# Procesando 595/57525: SII.TO
# Procesando 596/57525: 1725.HK
# Procesando 597/57525: 2445.T
# Procesando 598/57525: 600135.SS
# Procesando 599/57525: ZBAO
# Procesando 600/57525: WTIZ.DE
# Procesando 601/57525: CHALF
# Procesando 602/57525: DANUBE.BO
# Procesando 603/57525: NWGSX
# Procesando 604/57525: CMPD
# Procesando 605/57525: COOK
# Procesando 606/57525: 002600.SZ
# Procesando 607/57525: 6363.T
# Procesando 608/57525: BPTIX
# Procesando 609/57525: SFLM
# Procesando 610/57525: ISUN.L
# Procesando 611/57525: IUSU.DE
# Procesando 612/57525: TAKE.BO
# Procesando 613/57525: NDEKY
# Procesando 614/57525: 688526.SS
# Procesando 615/57525: 2258.HK
# Procesando 616/57525: MOBX
# Procesando 617/57525: IRCTC.NS
# Procesando 618/57525: CSAN3.SA
# Procesando 619/57525: UEPEN
# Procesando 620/57525: 003570.KS
# Procesando 621/57525: 600691.SS
# Procesando 622/57525: CLIG.L
# Procesando 623/57525: PRAJIND.BO
# Procesando 624/57525: ENGI11.SA
# Procesando 625/57525: H02.SI
# Procesando 626/57525: 2715.T
# Procesando 627/57525: 0IW7.L
# Procesando 628/57525: SKTO
# Procesando 629/57525: CPAC
# Procesando 630/57525: GNGBY
# Procesando 631/57525: MERC
# Procesando 632/57525: VPRB
# Procesando 633/57525: JOBBX
# Procesando 634/57525: TSNAX
# Procesando 635/57525: NCTKY
# Procesando 636/57525: 1907.HK
# Procesando 637/57525: 0136.HK
# Procesando 638/57525: 8071.HK
# Procesando 639/57525: 9505.T
# Procesando 640/57525: FRVIA.PA
# Procesando 641/57525: CGHOF
# Procesando 642/57525: GIB.AX
# Procesando 643/57525: TUPY3.SA
# Procesando 644/57525: 3153.T
# Procesando 645/57525: LU2082996898.SG
# Procesando 646/57525: SBUL.L
# Procesando 647/57525: BRAP3.SA
# Procesando 648/57525: 9507.T
# Procesando 649/57525: LACFX
# Procesando 650/57525: SKFINDIA.BO
# Procesando 651/57525: AAVVF
# Procesando 652/57525: 1558.TW
# Procesando 653/57525: 603080.SS
# Procesando 654/57525: ALADO.PA
# Procesando 655/57525: SHREMETAL.BO
# Procesando 656/57525: PAUSHAKLTD.BO
# Procesando 657/57525: PASUSPG.BO
# Procesando 658/57525: DHANBANK.BO
# Procesando 659/57525: ALT
# Procesando 660/57525: BIGG
# Procesando 661/57525: 3992.T
# Procesando 662/57525: TECHNOE.BO
# Procesando 663/57525: 1128.HK
# Procesando 664/57525: EW
# Procesando 665/57525: DEVM
# Procesando 666/57525: KAY.L
# Procesando 667/57525: CVR
# Procesando 668/57525: SLH.AX
# Procesando 669/57525: NLSPW
# Procesando 670/57525: CJR-B.TO
# Procesando 671/57525: EOF.AX
# Procesando 672/57525: SYAAF
# Procesando 673/57525: 6744.T
# Procesando 674/57525: TOGOF
# Procesando 675/57525: OPCE.TA
# Procesando 676/57525: THOMASCOOK.NS
# Procesando 677/57525: 2491.TW
# Procesando 678/57525: SEHCF
# Procesando 679/57525: 9929.TW
# Procesando 680/57525: 688261.SS
# Procesando 681/57525: WAL-PA
# Procesando 682/57525: MASQ.AE
# Procesando 683/57525: 8850.T
# Procesando 684/57525: MAVI.IS
# Procesando 685/57525: JSM
# Procesando 686/57525: PHPD.L
# Procesando 687/57525: 000096.SZ
# Procesando 688/57525: CDLR
# Procesando 689/57525: 603356.SS
# Procesando 690/57525: AKR.V
# Procesando 691/57525: PFH
# Procesando 692/57525: RADAAN.BO
# Procesando 693/57525: WAWIO.XD
# Procesando 694/57525: 307520.KS
# Procesando 695/57525: CFOK
# Procesando 696/57525: HMS.ST
# Procesando 697/57525: XDSCX
# Procesando 698/57525: 6743.TW
# Procesando 699/57525: HYLD.L
# Procesando 700/57525: PKK.CN
# Procesando 701/57525: 2120.T
# Procesando 702/57525: EACO
# Procesando 703/57525: 3550.TW
# Procesando 704/57525: 600897.SS
# Procesando 705/57525: GINDX
# Procesando 706/57525: 603388.SS
# Procesando 707/57525: CRES.CN
# Procesando 708/57525: 2202.HK
# Procesando 709/57525: HUDCO.NS
# Procesando 710/57525: 300888.SZ
# Procesando 711/57525: DNOPY
# Procesando 712/57525: BRMI.TO
# Procesando 713/57525: USIM5.SA
# Procesando 714/57525: 099430.KQ
# Procesando 715/57525: LYKISLTD.BO
# Procesando 716/57525: MDST
# Procesando 717/57525: OGSP
# Procesando 718/57525: OOSP
# Procesando 719/57525: DCII.JK
# Procesando 720/57525: CPRX
# Procesando 721/57525: ETFSAP.JO
# Procesando 722/57525: 0H38.L
# Procesando 723/57525: 0902.HK
# Procesando 724/57525: 000816.SZ
# Procesando 725/57525: MULT3.SA
# Procesando 726/57525: SFC.AX
# Procesando 727/57525: LIGT3.SA
# Procesando 728/57525: BALL
# Procesando 729/57525: ACSO.L
# Procesando 730/57525: 0HN1.L
# Procesando 731/57525: 2496.HK
# Procesando 732/57525: N3IA.F
# Procesando 733/57525: 1875.HK
# Procesando 734/57525: 4130.SR
# Procesando 735/57525: 2886.TW
# Procesando 736/57525: SMCP.PA
# Procesando 737/57525: FCSSOFT.BO
# Procesando 738/57525: 1030.HK
# Procesando 739/57525: FREJA.ST
# Procesando 740/57525: NNDM
# Procesando 741/57525: HRS.DE
# Procesando 742/57525: 0I58.L
# Procesando 743/57525: 950160.KQ
# Procesando 744/57525: 1080.SR
# Procesando 745/57525: 3494.TW
# Procesando 746/57525: 300607.SZ
# Procesando 747/57525: PGAS
# Procesando 748/57525: RTSN.TA
# Procesando 749/57525: AM3S.L
# Procesando 750/57525: PAULX
# Procesando 751/57525: IUGA.L
# Procesando 752/57525: DMMX.JK
# Procesando 753/57525: OTTV
# Procesando 754/57525: SPH
# Procesando 755/57525: 002768.SZ
# Procesando 756/57525: ZPR.TO
# Procesando 757/57525: BRKM5.SA
# Procesando 758/57525: MORT
# Procesando 759/57525: GFL.NZ
# Procesando 760/57525: ESIC.DE
# Procesando 761/57525: 0IQE.L
# Procesando 762/57525: 002878.SZ
# Procesando 763/57525: MMACX
# Procesando 764/57525: SEER3.SA
# Procesando 765/57525: TYOYY
# Procesando 766/57525: ALGEF
# Procesando 767/57525: BVEFX
# Procesando 768/57525: CSSX5E.MI
# Procesando 769/57525: 300450.SZ
# Procesando 770/57525: OODH
# Procesando 771/57525: QBR-B.TO
# Procesando 772/57525: CMCX.L
# Procesando 773/57525: NUZE
# Procesando 774/57525: GWTI
# Procesando 775/57525: TKOMY
# Procesando 776/57525: 1OJ.F
# Procesando 777/57525: NCSYF
# Procesando 778/57525: 002718.SZ
# Procesando 779/57525: 0127.KL
# Procesando 780/57525: ALK.AX
# Procesando 781/57525: VNQI
# Procesando 782/57525: PMMAF
# Procesando 783/57525: 6225.TW
# Procesando 784/57525: FCN
# Procesando 785/57525: 6742.KL
# Procesando 786/57525: 0UYO.L
# Procesando 787/57525: SPRN
# Procesando 788/57525: TWC.TO
# Procesando 789/57525: 1233.HK
# Procesando 790/57525: 2503.T
# Procesando 791/57525: RCIIX
# Procesando 792/57525: UAMM
# Procesando 793/57525: GGPS3.SA
# Procesando 794/57525: ZUD.TO
# Procesando 795/57525: TQCD.TO
# Procesando 796/57525: 600867.SS
# Procesando 797/57525: 0031.HK
# Procesando 798/57525: 603535.SS
# Procesando 799/57525: JGMNX
# Procesando 800/57525: BPAN4.SA
# Procesando 801/57525: PTBL3.SA
# Procesando 802/57525: 0HPW.L
# Procesando 803/57525: 300641.SZ
# Procesando 804/57525: JXHLY
# Procesando 805/57525: OMAXE.NS
# Procesando 806/57525: 1155.KL
# Procesando 807/57525: RWT
# Procesando 808/57525: FRAS3.SA
# Procesando 809/57525: 2497.T
# Procesando 810/57525: TORXF
# Procesando 811/57525: FRUC.L
# Procesando 812/57525: PROCLB.BO
# Procesando 813/57525: MTLHY
# Procesando 814/57525: UTRE
# Procesando 815/57525: RIBT
# Procesando 816/57525: PREV.CN
# Procesando 817/57525: FRFC
# Procesando 818/57525: 1820.T
# Procesando 819/57525: STBP3.SA
# Procesando 820/57525: KGH.L
# Procesando 821/57525: BHB
# Procesando 822/57525: RILYK
# Procesando 823/57525: 0085.HK
# Procesando 824/57525: 0QR3.L
# Procesando 825/57525: CWEGF
# Procesando 826/57525: 2915.T
# Procesando 827/57525: KNBIF
# Procesando 828/57525: PNOYX
# Procesando 829/57525: FMNL.BO
# Procesando 830/57525: UMEWF
# Procesando 831/57525: BLZE
# Procesando 832/57525: 0K6M.L
# Procesando 833/57525: NAVA.BO
# Procesando 834/57525: HALDER.BO
# Procesando 835/57525: WEISTA.CO
# Procesando 836/57525: TRINL
# Procesando 837/57525: CRH.L
# Procesando 838/57525: 300021.SZ
# Procesando 839/57525: 5148.KL
# Procesando 840/57525: 300558.SZ
# Procesando 841/57525: STLTECH.BO
# Procesando 842/57525: TGP.AX
# Procesando 843/57525: MEGASTAR.NS
# Procesando 844/57525: ENZN
# Procesando 845/57525: BNAIW
# Procesando 846/57525: AGMJF
# Procesando 847/57525: REZI
# Procesando 848/57525: 008110.KS
# Procesando 849/57525: AINN.DE
# Procesando 850/57525: CRLA.PA
# Procesando 851/57525: ALCYB.PA
# Procesando 852/57525: STG
# Procesando 853/57525: RICOY
# Procesando 854/57525: C6L.SI
# Procesando 855/57525: DISMX
# Procesando 856/57525: BUR.L
# Procesando 857/57525: DIM
# Procesando 858/57525: PQVM.L
# Procesando 859/57525: CVX
# Procesando 860/57525: AIHL.BO
# Procesando 861/57525: 600808.SS
# Procesando 862/57525: 000655.SZ
# Procesando 863/57525: BIDU
# Procesando 864/57525: 1447.HK
# Procesando 865/57525: ECDAW
# Procesando 866/57525: 9633.T
# Procesando 867/57525: 603869.SS
# Procesando 868/57525: ANSALAPI.NS
# Procesando 869/57525: DIS
# Procesando 870/57525: 200541.SZ
# Procesando 871/57525: 145A.T
# Procesando 872/57525: CMRA
# Procesando 873/57525: RLIA.MC
# Procesando 874/57525: IQQQ
# Procesando 875/57525: 122450.KQ
# Procesando 876/57525: 8381.T
# Procesando 877/57525: BWEN
# Procesando 878/57525: USY.L
# Procesando 879/57525: L3H.F
# Procesando 880/57525: SRBCF
# Procesando 881/57525: FHKAX
# Procesando 882/57525: 0049.KL
# Procesando 883/57525: TUI.L
# Procesando 884/57525: 298690.KS
# Procesando 885/57525: NUC.AX
# Procesando 886/57525: 105840.KS
# Procesando 887/57525: 002394.SZ
# Procesando 888/57525: XRLV
# Procesando 889/57525: TORM
# Procesando 890/57525: 4043.T
# Procesando 891/57525: 000026.SZ
# Procesando 892/57525: 002203.SZ
# Procesando 893/57525: T
# Procesando 894/57525: CMRE-PD
# Procesando 895/57525: 003043.SZ
# Procesando 896/57525: BIK-PA.TO
# Procesando 897/57525: SSYS
# Procesando 898/57525: 002890.SZ
# Procesando 899/57525: IBREALEST.BO
# Procesando 900/57525: SVI.BK
# Procesando 901/57525: INDY.JK
# Procesando 902/57525: 002388.SZ
# Procesando 903/57525: WAAEX
# Procesando 904/57525: 0236.HK
# Procesando 905/57525: 000338.SZ
# Procesando 906/57525: CLOD
# Procesando 907/57525: 1978.HK
# Procesando 908/57525: 600594.SS
# Procesando 909/57525: XOM
# Procesando 910/57525: PBCRF
# Procesando 911/57525: IZB.WA
# Procesando 912/57525: 002410.SZ
# Procesando 913/57525: KC.BK
# Procesando 914/57525: TRUG
# Procesando 915/57525: BOXL
# Procesando 916/57525: PPBT.TA
# Procesando 917/57525: RGNX
# Procesando 918/57525: CLE.AX
# Procesando 919/57525: BNR
# Procesando 920/57525: 6417.T
# Procesando 921/57525: SWTRX
# Procesando 922/57525: 5094.KL
# Procesando 923/57525: LSRCF
# Procesando 924/57525: LGF-B
# Procesando 925/57525: CXMSF
# Procesando 926/57525: SNNUF
# Procesando 927/57525: HPMCF
# Procesando 928/57525: KEL.DE
# Procesando 929/57525: FTT.TO
# Procesando 930/57525: EDTXF
# Procesando 931/57525: 9731.T
# Procesando 932/57525: CNVVY
# Procesando 933/57525: WDHR
# Procesando 934/57525: CHGCF
# Procesando 935/57525: GATECH.NS
# Procesando 936/57525: AGXY3.SA
# Procesando 937/57525: 000157.SZ
# Procesando 938/57525: SACH-PA
# Procesando 939/57525: PERK.CN
# Procesando 940/57525: HNSC.L
# Procesando 941/57525: SAGAR.BO
# Procesando 942/57525: 2516.HK
# Procesando 943/57525: SOF.BR
# Procesando 944/57525: PRAENG.NS
# Procesando 945/57525: 002622.SZ
# Procesando 946/57525: SUEZF
# Procesando 947/57525: 5393.T
# Procesando 948/57525: HITI
# Procesando 949/57525: ORENF
# Procesando 950/57525: ETTE.HE
# Procesando 951/57525: DYN
# Procesando 952/57525: APRAF
# Procesando 953/57525: VASO
# Procesando 954/57525: 605567.SS
# Procesando 955/57525: 1775.T
# Procesando 956/57525: C09.SI
# Procesando 957/57525: FEML.L
# Procesando 958/57525: 6472.TW
# Procesando 959/57525: MAXI
# Procesando 960/57525: LJPY.L
# Procesando 961/57525: AUA.AX
# Procesando 962/57525: BBOX.L
# Procesando 963/57525: FTUIX
# Procesando 964/57525: NMFCZ
# Procesando 965/57525: 600629.SS
# Procesando 966/57525: 001333.SZ
# Procesando 967/57525: FGPHF
# Procesando 968/57525: CEROW
# Procesando 969/57525: ZIN.L
# Procesando 970/57525: SNOWMAN.BO
# Procesando 971/57525: FRONTCORP.BO
# Procesando 972/57525: 601231.SS
# Procesando 973/57525: GRHI
# Procesando 974/57525: QUINTEGRA.NS
# Procesando 975/57525: YMAX.AX
# Procesando 976/57525: LKFN
# Procesando 977/57525: ALTR
# Procesando 978/57525: CFFN
# Procesando 979/57525: TATYY
# Procesando 980/57525: 0L4F.L
# Procesando 981/57525: SWRBY
# Procesando 982/57525: BOF
# Procesando 983/57525: HERITGFOOD.BO
# Procesando 984/57525: 468760.KQ
# Procesando 985/57525: DCOMP
# Procesando 986/57525: WTTR
# Procesando 987/57525: MKPL.NS
# Procesando 988/57525: DGH.AX
# Procesando 989/57525: PSTG
# Procesando 990/57525: PODDARMENT.NS
# Procesando 991/57525: SKKY
# Procesando 992/57525: 603016.SS
# Procesando 993/57525: 601997.SS
# Procesando 994/57525: KPELY
# Procesando 995/57525: 023800.KS
# Procesando 996/57525: 7100.KL
# Procesando 997/57525: DUERF
# Procesando 998/57525: UCPLF
# Procesando 999/57525: MLS.WA
# Procesando 1000/57525: 1803.T
# Procesando 1001/57525: NEA.MC
# Procesando 1002/57525: 603757.SS
# Procesando 1003/57525: BONAS.ST
# Procesando 1004/57525: 001266.SZ
# Procesando 1005/57525: DELL
# Procesando 1006/57525: 605180.SS
# Procesando 1007/57525: 036540.KQ
# Procesando 1008/57525: VTXPF
# Procesando 1009/57525: 002546.SZ
# Procesando 1010/57525: IPGP
# Procesando 1011/57525: PTCHF
# Procesando 1012/57525: LUVU
# Procesando 1013/57525: DPYG.L
# Procesando 1014/57525: SONDA.SN
# Procesando 1015/57525: KIKOF
# Procesando 1016/57525: PREMIERPOL.BO
# Procesando 1017/57525: 300829.SZ
# Procesando 1018/57525: 2LYA.F
# Procesando 1019/57525: 2727.TW
# Procesando 1020/57525: MCRAB
# Procesando 1021/57525: SITINET.NS
# Procesando 1022/57525: BEMO.L
# Procesando 1023/57525: 011785.KS
# Procesando 1024/57525: GSBD
# Procesando 1025/57525: 2772.HK
# Procesando 1026/57525: BIOAF
# Procesando 1027/57525: DECK
# Procesando 1028/57525: 0KBI.L
# Procesando 1029/57525: 8167.T
# Procesando 1030/57525: SOP.PA
# Procesando 1031/57525: RIGS.JK
# Procesando 1032/57525: FOO.DE
# Procesando 1033/57525: 002431.SZ
# Procesando 1034/57525: FBTT
# Procesando 1035/57525: VTRS
# Procesando 1036/57525: HMI.WA
# Procesando 1037/57525: 002364.SZ
# Procesando 1038/57525: 034730.KS
# Procesando 1039/57525: LXCHEM.BO
# Procesando 1040/57525: BIG.TA
# Procesando 1041/57525: 600029.SS
# Procesando 1042/57525: E3X1.DE
# Procesando 1043/57525: 1651.KL
# Procesando 1044/57525: VREX
# Procesando 1045/57525: 300119.SZ
# Procesando 1046/57525: FSYRX
# Procesando 1047/57525: TEDE.TA
# Procesando 1048/57525: 5707.T
# Procesando 1049/57525: HAVELLS.NS
# Procesando 1050/57525: MTB
# Procesando 1051/57525: KESKOA.HE
# Procesando 1052/57525: PHOE.TA
# Procesando 1053/57525: AVONMORE.NS
# Procesando 1054/57525: 301191.SZ
# Procesando 1055/57525: SEIGY
# Procesando 1056/57525: 7532.T
# Procesando 1057/57525: TRF.NS
# Procesando 1058/57525: BZUN
# Procesando 1059/57525: CARS
# Procesando 1060/57525: GTIM
# Procesando 1061/57525: STGAF
# Procesando 1062/57525: CBKD.IL
# Procesando 1063/57525: GBX
# Procesando 1064/57525: EIHOTEL.NS
# Procesando 1065/57525: BAC-PP
# Procesando 1066/57525: 4107.TWO
# Procesando 1067/57525: 603955.SS
# Procesando 1068/57525: RBN.L
# Procesando 1069/57525: BHG.ST
# Procesando 1070/57525: 600119.SS
# Procesando 1071/57525: USB-PR
# Procesando 1072/57525: SJRNF
# Procesando 1073/57525: 122260.KS
# Procesando 1074/57525: 1176.HK
# Procesando 1075/57525: YUKEN.BO
# Procesando 1076/57525: 006090.KS
# Procesando 1077/57525: 600685.SS
# Procesando 1078/57525: JPTXF
# Procesando 1079/57525: DEWA.JK
# Procesando 1080/57525: GIGSEK.ST
# Procesando 1081/57525: GIB
# Procesando 1082/57525: 1204.HK
# Procesando 1083/57525: 090360.KQ
# Procesando 1084/57525: V60D.DE
# Procesando 1085/57525: MDU
# Procesando 1086/57525: MTEDUCARE.BO
# Procesando 1087/57525: 1193.HK
# Procesando 1088/57525: 6637.T
# Procesando 1089/57525: WCH.DE
# Procesando 1090/57525: 600330.SS
# Procesando 1091/57525: ITUB3.SA
# Procesando 1092/57525: JRPT.JK
# Procesando 1093/57525: GNMSF
# Procesando 1094/57525: HFFG
# Procesando 1095/57525: LSSIX
# Procesando 1096/57525: 8163.HK
# Procesando 1097/57525: SETCO.NS
# Procesando 1098/57525: 4197.KL
# Procesando 1099/57525: SNN
# Procesando 1100/57525: AOSL
# Procesando 1101/57525: 300819.SZ
# Procesando 1102/57525: VFSUX
# Procesando 1103/57525: V40A.DE
# Procesando 1104/57525: 0422.HK
# Procesando 1105/57525: VGS.AX
# Procesando 1106/57525: DBXJ.DE
# Procesando 1107/57525: QRNNF
# Procesando 1108/57525: SKPMIL.BO
# Procesando 1109/57525: INQD
# Procesando 1110/57525: 5759.T
# Procesando 1111/57525: BCG.BO
# Procesando 1112/57525: ARAO
# Procesando 1113/57525: DITHF
# Procesando 1114/57525: VEE.DE
# Procesando 1115/57525: FOVAX
# Procesando 1116/57525: TROW
# Procesando 1117/57525: ALIM
# Procesando 1118/57525: XVIPY
# Procesando 1119/57525: ORIENTELEC.BO
# Procesando 1120/57525: KB
# Procesando 1121/57525: 196030.KS
# Procesando 1122/57525: CNGLU
# Procesando 1123/57525: 8070.T
# Procesando 1124/57525: 6963.T
# Procesando 1125/57525: KIDS
# Procesando 1126/57525: SPMV.L
# Procesando 1127/57525: 5530.TWO
# Procesando 1128/57525: 0929.HK
# Procesando 1129/57525: EQUITASBNK.BO
# Procesando 1130/57525: LGI
# Procesando 1131/57525: 4539.T
# Procesando 1132/57525: BIV10.CO
# Procesando 1133/57525: VIPS
# Procesando 1134/57525: SPCB
# Procesando 1135/57525: 9034.T
# Procesando 1136/57525: SURG
# Procesando 1137/57525: CTSO
# Procesando 1138/57525: SE.CN
# Procesando 1139/57525: TBCG.L
# Procesando 1140/57525: DEXSF
# Procesando 1141/57525: GLDD
# Procesando 1142/57525: MDRX
# Procesando 1143/57525: 8241.HK
# Procesando 1144/57525: ALANKIT.NS
# Procesando 1145/57525: RCC
# Procesando 1146/57525: KEGX
# Procesando 1147/57525: AGUA.MX
# Procesando 1148/57525: BYDDY
# Procesando 1149/57525: ASLRF
# Procesando 1150/57525: ESHDF
# Procesando 1151/57525: BB
# Procesando 1152/57525: EXM.BR
# Procesando 1153/57525: 601665.SS
# Procesando 1154/57525: PUBM
# Procesando 1155/57525: CEBU.DE
# Procesando 1156/57525: QCI.DE
# Procesando 1157/57525: 300753.SZ
# Procesando 1158/57525: 6406.T
# Procesando 1159/57525: CRPJY
# Procesando 1160/57525: BHARTIARTL.BO
# Procesando 1161/57525: GPS
# Procesando 1162/57525: DLG.L
# Procesando 1163/57525: RITES.BO
# Procesando 1164/57525: 032820.KQ
# Procesando 1165/57525: 8005.HK
# Procesando 1166/57525: EFF.DE
# Procesando 1167/57525: SGR.SI
# Procesando 1168/57525: 0107.HK
# Procesando 1169/57525: ONTF
# Procesando 1170/57525: 0926.HK
# Procesando 1171/57525: 002016.SZ
# Procesando 1172/57525: CATL.L
# Procesando 1173/57525: STAR.JK
# Procesando 1174/57525: ADCT
# Procesando 1175/57525: HES
# Procesando 1176/57525: LVG.V
# Procesando 1177/57525: 0HWH.L
# Procesando 1178/57525: 603327.SS
# Procesando 1179/57525: 603948.SS
# Procesando 1180/57525: SIXL
# Procesando 1181/57525: 002497.SZ
# Procesando 1182/57525: 002319.SZ
# Procesando 1183/57525: 5222.KL
# Procesando 1184/57525: CAJFF
# Procesando 1185/57525: 000833.SZ
# Procesando 1186/57525: DRKTY
# Procesando 1187/57525: TASE.TA
# Procesando 1188/57525: 2183.T
# Procesando 1189/57525: 002690.SZ
# Procesando 1190/57525: KLYCY
# Procesando 1191/57525: LONCF
# Procesando 1192/57525: NTAC
# Procesando 1193/57525: BFS
# Procesando 1194/57525: 600637.SS
# Procesando 1195/57525: JROOF
# Procesando 1196/57525: LANDM
# Procesando 1197/57525: 0LO3.L
# Procesando 1198/57525: IBM
# Procesando 1199/57525: ORCA.L
# Procesando 1200/57525: TURSG.IS
# Procesando 1201/57525: SOHON
# Procesando 1202/57525: NICH
# Procesando 1203/57525: IBP
# Procesando 1204/57525: EOT.L
# Procesando 1205/57525: WEGE3.SA
# Procesando 1206/57525: 1083.HK
# Procesando 1207/57525: NOV
# Procesando 1208/57525: 0P000185T4.L
# Procesando 1209/57525: AWI
# Procesando 1210/57525: 6504.T
# Procesando 1211/57525: PETKM.IS
# Procesando 1212/57525: 002707.SZ
# Procesando 1213/57525: FBTAX
# Procesando 1214/57525: XMTW.L
# Procesando 1215/57525: OUT.JO
# Procesando 1216/57525: 002955.SZ
# Procesando 1217/57525: LESL
# Procesando 1218/57525: CSSMIM.SW
# Procesando 1219/57525: GHQPX
# Procesando 1220/57525: NVST
# Procesando 1221/57525: 0LD9.L
# Procesando 1222/57525: 0272.HK
# Procesando 1223/57525: 1088.HK
# Procesando 1224/57525: JMPLF
# Procesando 1225/57525: 1709.TW
# Procesando 1226/57525: 603918.SS
# Procesando 1227/57525: FPH
# Procesando 1228/57525: EIFF.PA
# Procesando 1229/57525: 603789.SS
# Procesando 1230/57525: 3TYL.L
# Procesando 1231/57525: JD.L
# Procesando 1232/57525: 6293.T
# Procesando 1233/57525: 2897.T
# Procesando 1234/57525: 5311.KL
# Procesando 1235/57525: FTXH
# Procesando 1236/57525: 002247.SZ
# Procesando 1237/57525: IICN
# Procesando 1238/57525: JSP.BK
# Procesando 1239/57525: 2430.TW
# Procesando 1240/57525: NKLA
# Procesando 1241/57525: 002457.SZ
# Procesando 1242/57525: XVIVO.ST
# Procesando 1243/57525: ARPT.TA
# Procesando 1244/57525: TXT.MI
# Procesando 1245/57525: OCT.AX
# Procesando 1246/57525: 3LDE.L
# Procesando 1247/57525: VR.CN
# Procesando 1248/57525: CORN
# Procesando 1249/57525: CWT.BK
# Procesando 1250/57525: 2377.HK
# Procesando 1251/57525: BRES.QA
# Procesando 1252/57525: 2020.HK
# Procesando 1253/57525: NEM.DE
# Procesando 1254/57525: 1638.HK
# Procesando 1255/57525: WRTBY
# Procesando 1256/57525: NHMFX
# Procesando 1257/57525: IDCBY
# Procesando 1258/57525: HKBV
# Procesando 1259/57525: 9759.T
# Procesando 1260/57525: CRMAX
# Procesando 1261/57525: DO
# Procesando 1262/57525: DP4B.DE
# Procesando 1263/57525: RAMCOSYS.BO
# Procesando 1264/57525: 0KAB.L
# Procesando 1265/57525: 1938.HK
# Procesando 1266/57525: NVEE
# Procesando 1267/57525: SANDHAR.BO
# Procesando 1268/57525: FCT.MI
# Procesando 1269/57525: MITQ
# Procesando 1270/57525: MCCRF
# Procesando 1271/57525: 1776.T
# Procesando 1272/57525: DWNI.DE
# Procesando 1273/57525: ALB.MC
# Procesando 1274/57525: 0945.HK
# Procesando 1275/57525: NOTE-WT
# Procesando 1276/57525: 8337.HK
# Procesando 1277/57525: MTZ
# Procesando 1278/57525: ASII.JK
# Procesando 1279/57525: IDEAFORGE.NS
# Procesando 1280/57525: HFBK
# Procesando 1281/57525: SCR.SW
# Procesando 1282/57525: IGC.L
# Procesando 1283/57525: TAJ.V
# Procesando 1284/57525: SQFTW
# Procesando 1285/57525: 206650.KQ
# Procesando 1286/57525: 688088.SS
# Procesando 1287/57525: MUNJALAU.NS
# Procesando 1288/57525: PSD.TO
# Procesando 1289/57525: 2314.HK
# Procesando 1290/57525: RAF.WA
# Procesando 1291/57525: 688697.SS
# Procesando 1292/57525: BTCW.SW
# Procesando 1293/57525: BCOM.L
# Procesando 1294/57525: 8864.T
# Procesando 1295/57525: 2511.HK
# Procesando 1296/57525: CELUW
# Procesando 1297/57525: NERD.CN
# Procesando 1298/57525: AKBTY
# Procesando 1299/57525: DOPPLER.AT
# Procesando 1300/57525: DMGGF
# Procesando 1301/57525: ADTX
# Procesando 1302/57525: NVV1.F
# Procesando 1303/57525: HUG.TO
# Procesando 1304/57525: JPAS.L
# Procesando 1305/57525: 603298.SS
# Procesando 1306/57525: AERO.SW
# Procesando 1307/57525: CFWIX
# Procesando 1308/57525: ARTNA
# Procesando 1309/57525: BETE
# Procesando 1310/57525: 603429.SS
# Procesando 1311/57525: DRAL.TA
# Procesando 1312/57525: 0QS9.L
# Procesando 1313/57525: KVYO
# Procesando 1314/57525: SAHN.SW
# Procesando 1315/57525: NAHARSPING.BO
# Procesando 1316/57525: 600579.SS
# Procesando 1317/57525: JDEP.AS
# Procesando 1318/57525: 6029.T
# Procesando 1319/57525: SMWH.L
# Procesando 1320/57525: 5821.T
# Procesando 1321/57525: FLYX
# Procesando 1322/57525: MX
# Procesando 1323/57525: FNLC
# Procesando 1324/57525: STHS.L
# Procesando 1325/57525: 601116.SS
# Procesando 1326/57525: NNND.VI
# Procesando 1327/57525: GMS
# Procesando 1328/57525: ARGGY
# Procesando 1329/57525: IE00BM9TSP27.SG
# Procesando 1330/57525: FRSX.TA
# Procesando 1331/57525: CYIENT.NS
# Procesando 1332/57525: KREBSBIO.NS
# Procesando 1333/57525: 6407.T
# Procesando 1334/57525: NTI.AX
# Procesando 1335/57525: 189300.KQ
# Procesando 1336/57525: VVV
# Procesando 1337/57525: NA9.F
# Procesando 1338/57525: 0659.HK
# Procesando 1339/57525: HFG.L
# Procesando 1340/57525: BGU.TO
# Procesando 1341/57525: BTZ
# Procesando 1342/57525: ANR.AX
# Procesando 1343/57525: CLPI.JK
# Procesando 1344/57525: WXIBF
# Procesando 1345/57525: BML-PL
# Procesando 1346/57525: PALREDTEC.NS
# Procesando 1347/57525: LDVAX
# Procesando 1348/57525: 067310.KQ
# Procesando 1349/57525: 009540.KS
# Procesando 1350/57525: 600854.SS
# Procesando 1351/57525: TULAV.HE
# Procesando 1352/57525: STEL
# Procesando 1353/57525: AER.AX
# Procesando 1354/57525: 600213.SS
# Procesando 1355/57525: FUR.AS
# Procesando 1356/57525: NYMTM
# Procesando 1357/57525: MOBO
# Procesando 1358/57525: GIFI
# Procesando 1359/57525: TGNA
# Procesando 1360/57525: 002111.SZ
# Procesando 1361/57525: 0JD3.L
# Procesando 1362/57525: GMLPF
# Procesando 1363/57525: WSBF
# Procesando 1364/57525: PNNX
# Procesando 1365/57525: HUSCO.CO
# Procesando 1366/57525: GORV
# Procesando 1367/57525: 1180.SR
# Procesando 1368/57525: FNBT
# Procesando 1369/57525: FKASX
# Procesando 1370/57525: PTTG.F
# Procesando 1371/57525: ZUE.WA
# Procesando 1372/57525: ELIN.BO
# Procesando 1373/57525: 300627.SZ
# Procesando 1374/57525: COM.MC
# Procesando 1375/57525: PTEZX
# Procesando 1376/57525: 243070.KQ
# Procesando 1377/57525: PANACEABIO.NS
# Procesando 1378/57525: GICRE.NS
# Procesando 1379/57525: AGMH
# Procesando 1380/57525: GOLD.TA
# Procesando 1381/57525: 133820.KS
# Procesando 1382/57525: SPHC.MI
# Procesando 1383/57525: 002125.SZ
# Procesando 1384/57525: 508026.SS
# Procesando 1385/57525: BUCN.SW
# Procesando 1386/57525: CGA
# Procesando 1387/57525: D
# Procesando 1388/57525: PBMWW
# Procesando 1389/57525: 600875.SS
# Procesando 1390/57525: CMP.AX
# Procesando 1391/57525: TOVX
# Procesando 1392/57525: VG0K.F
# Procesando 1393/57525: ODD
# Procesando 1394/57525: 605177.SS
# Procesando 1395/57525: TLGAX
# Procesando 1396/57525: 8225.HK
# Procesando 1397/57525: DMB
# Procesando 1398/57525: SAREGAMA.BO
# Procesando 1399/57525: SVCTF
# Procesando 1400/57525: PBIT.CN
# Procesando 1401/57525: 068240.KQ
# Procesando 1402/57525: ALCE
# Procesando 1403/57525: 084370.KQ
# Procesando 1404/57525: LEN.WA
# Procesando 1405/57525: 300825.SZ
# Procesando 1406/57525: UBER
# Procesando 1407/57525: FZR.AX
# Procesando 1408/57525: FLAU
# Procesando 1409/57525: MRPLY
# Procesando 1410/57525: BHVN
# Procesando 1411/57525: GODREJPROP.BO
# Procesando 1412/57525: 047050.KS
# Procesando 1413/57525: WDFC
# Procesando 1414/57525: YUM
# Procesando 1415/57525: 1916.HK
# Procesando 1416/57525: PERM.BK
# Procesando 1417/57525: 605077.SS
# Procesando 1418/57525: 050890.KQ
# Procesando 1419/57525: XBAP
# Procesando 1420/57525: BCDAW
# Procesando 1421/57525: ARAD.TA
# Procesando 1422/57525: 5957.T
# Procesando 1423/57525: 9761.T
# Procesando 1424/57525: SHINEFASH.BO
# Procesando 1425/57525: GXI.DE
# Procesando 1426/57525: WFC-PD
# Procesando 1427/57525: NET
# Procesando 1428/57525: 033250.KS
# Procesando 1429/57525: ALBFR.PA
# Procesando 1430/57525: OPW.V
# Procesando 1431/57525: PBH
# Procesando 1432/57525: 7272.T
# Procesando 1433/57525: IMC.AX
# Procesando 1434/57525: 300969.SZ
# Procesando 1435/57525: 301180.SZ
# Procesando 1436/57525: MS
# Procesando 1437/57525: 0045.HK
# Procesando 1438/57525: 056080.KQ
# Procesando 1439/57525: 2359.T
# Procesando 1440/57525: NWPX
# Procesando 1441/57525: 0966.HK
# Procesando 1442/57525: 002642.SZ
# Procesando 1443/57525: PEO
# Procesando 1444/57525: 2131.HK
# Procesando 1445/57525: OJC.AX
# Procesando 1446/57525: 300050.SZ
# Procesando 1447/57525: FACT.BO
# Procesando 1448/57525: VLNSF
# Procesando 1449/57525: TVSSCS.BO
# Procesando 1450/57525: AAACX
# Procesando 1451/57525: PLYZ
# Procesando 1452/57525: JSHSX
# Procesando 1453/57525: 601177.SS
# Procesando 1454/57525: ECDA
# Procesando 1455/57525: 300886.SZ
# Procesando 1456/57525: MOLI.JK
# Procesando 1457/57525: AB.PA
# Procesando 1458/57525: GCP.L
# Procesando 1459/57525: GABRIEL.NS
# Procesando 1460/57525: CRON.TO
# Procesando 1461/57525: SEATV.BO
# Procesando 1462/57525: IFJPY
# Procesando 1463/57525: RFSL.BO
# Procesando 1464/57525: PFE.BA
# Procesando 1465/57525: 0KIT.L
# Procesando 1466/57525: NOV.AX
# Procesando 1467/57525: EXCS.L
# Procesando 1468/57525: AEP.L
# Procesando 1469/57525: 002779.SZ
# Procesando 1470/57525: 0274.HK
# Procesando 1471/57525: 0KZA.L
# Procesando 1472/57525: MANGCHEFER.BO
# Procesando 1473/57525: DCC.L
# Procesando 1474/57525: 603639.SS
# Procesando 1475/57525: 0574.HK
# Procesando 1476/57525: AMC
# Procesando 1477/57525: ROO.L
# Procesando 1478/57525: 002614.SZ
# Procesando 1479/57525: KNX
# Procesando 1480/57525: IPCIF
# Procesando 1481/57525: HESAY
# Procesando 1482/57525: CCL.L
# Procesando 1483/57525: ABSLAMC.BO
# Procesando 1484/57525: ALKLK.PA
# Procesando 1485/57525: 002691.SZ
# Procesando 1486/57525: DHSG.L
# Procesando 1487/57525: MAIFF
# Procesando 1488/57525: PYVAX
# Procesando 1489/57525: FGR.PA
# Procesando 1490/57525: 002686.SZ
# Procesando 1491/57525: TNA
# Procesando 1492/57525: HFBL
# Procesando 1493/57525: 0923.HK
# Procesando 1494/57525: USUE.DE
# Procesando 1495/57525: SIG.V
# Procesando 1496/57525: PRGO
# Procesando 1497/57525: INDUSFINL.BO
# Procesando 1498/57525: WRDLY
# Procesando 1499/57525: 0A23.L
# Procesando 1500/57525: HSSCX
# Procesando 1501/57525: 0O27.L
# Procesando 1502/57525: XYIGY
# Procesando 1503/57525: 114190.KQ
# Procesando 1504/57525: ZENITHSTL.NS
# Procesando 1505/57525: DRONACHRYA.BO
# Procesando 1506/57525: 0408.HK
# Procesando 1507/57525: COG.L
# Procesando 1508/57525: TKLF
# Procesando 1509/57525: LINC.NS
# Procesando 1510/57525: TKIM.JK
# Procesando 1511/57525: EFC
# Procesando 1512/57525: CIVI
# Procesando 1513/57525: VANDANA.BO
# Procesando 1514/57525: MOR
# Procesando 1515/57525: 7455.T
# Procesando 1516/57525: ALEX
# Procesando 1517/57525: 2152.HK
# Procesando 1518/57525: ACCELYA.NS
# Procesando 1519/57525: 2103.TW
# Procesando 1520/57525: HNSA.ST
# Procesando 1521/57525: JSDHX
# Procesando 1522/57525: UINF.DE
# Procesando 1523/57525: 000967.SZ
# Procesando 1524/57525: APGT
# Procesando 1525/57525: 3920.T
# Procesando 1526/57525: DITTF
# Procesando 1527/57525: IAIMCA.CO
# Procesando 1528/57525: C73.PA
# Procesando 1529/57525: 000157.KS
# Procesando 1530/57525: PGPHF
# Procesando 1531/57525: DRQ
# Procesando 1532/57525: FLSP
# Procesando 1533/57525: NOBH
# Procesando 1534/57525: HOT-UN.TO
# Procesando 1535/57525: 002853.SZ
# Procesando 1536/57525: TTX.CN
# Procesando 1537/57525: ARH.WA
# Procesando 1538/57525: YOU
# Procesando 1539/57525: 8495.HK
# Procesando 1540/57525: PREF
# Procesando 1541/57525: SIXJ
# Procesando 1542/57525: 002544.SZ
# Procesando 1543/57525: SYGGF
# Procesando 1544/57525: MARATHON.BO
# Procesando 1545/57525: TOPPY
# Procesando 1546/57525: CLF
# Procesando 1547/57525: 603603.SS
# Procesando 1548/57525: MMIRF
# Procesando 1549/57525: HHUSF
# Procesando 1550/57525: 0607.HK
# Procesando 1551/57525: IEX
# Procesando 1552/57525: DOGEF
# Procesando 1553/57525: 0OA4.L
# Procesando 1554/57525: IPE.WA
# Procesando 1555/57525: GCKL.BO
# Procesando 1556/57525: SHANTIGEAR.BO
# Procesando 1557/57525: PCBL.BO
# Procesando 1558/57525: QIIK.QA
# Procesando 1559/57525: 300922.SZ
# Procesando 1560/57525: 4291.SR
# Procesando 1561/57525: HHL.TO
# Procesando 1562/57525: 8420.HK
# Procesando 1563/57525: 4030.SR
# Procesando 1564/57525: EXS2.DE
# Procesando 1565/57525: MS-PO
# Procesando 1566/57525: BYDIY
# Procesando 1567/57525: RIEN.SW
# Procesando 1568/57525: 6677.HK
# Procesando 1569/57525: IAALF
# Procesando 1570/57525: PGNT
# Procesando 1571/57525: ALW.MI
# Procesando 1572/57525: 0Z1Q.L
# Procesando 1573/57525: 174360.KS
# Procesando 1574/57525: BML-PH
# Procesando 1575/57525: CMAKY
# Procesando 1576/57525: NXI.PA
# Procesando 1577/57525: ALDAR.PA
# Procesando 1578/57525: 9760.T
# Procesando 1579/57525: DAR
# Procesando 1580/57525: MULTI-X.SN
# Procesando 1581/57525: 3921.T
# Procesando 1582/57525: SPG
# Procesando 1583/57525: BINV.ST
# Procesando 1584/57525: NLY-PF
# Procesando 1585/57525: DEX.DE
# Procesando 1586/57525: GRCU
# Procesando 1587/57525: CMJIX
# Procesando 1588/57525: 3209.TW
# Procesando 1589/57525: BKAG
# Procesando 1590/57525: TTGT
# Procesando 1591/57525: HEQ
# Procesando 1592/57525: 310210.KQ
# Procesando 1593/57525: AG
# Procesando 1594/57525: 603258.SS
# Procesando 1595/57525: 1714.TW
# Procesando 1596/57525: IBCP
# Procesando 1597/57525: MUA
# Procesando 1598/57525: NFG
# Procesando 1599/57525: 300833.SZ
# Procesando 1600/57525: CVD.TO
# Procesando 1601/57525: PET
# Procesando 1602/57525: CCLDO
# Procesando 1603/57525: FISB
# Procesando 1604/57525: 5451.T
# Procesando 1605/57525: AALBF
# Procesando 1606/57525: HAPI
# Procesando 1607/57525: HMC
# Procesando 1608/57525: FNTN.DE
# Procesando 1609/57525: QBAK
# Procesando 1610/57525: CDGLY
# Procesando 1611/57525: FRA.DE
# Procesando 1612/57525: GDX.AX
# Procesando 1613/57525: 002377.SZ
# ...
# Procesando 57070/57525: FF.MI
# Procesando 57071/57525: SST.BK
# Procesando 57072/57525: 1301.T
# Procesando 57073/57525: NGS.AX
# Procesando 57074/57525: 002311.SZ
# Procesando 57075/57525: 8091.T
# Procesando 57076/57525: NSS
# Procesando 57077/57525: SENEB
# Procesando 57078/57525: CCO.AX
# Procesando 57079/57525: BRN
# Procesando 57080/57525: SCR.TO
# Procesando 57081/57525: DRNK
# Procesando 57082/57525: SUN
# Procesando 57083/57525: 000723.SZ
# Procesando 57084/57525: 0228.HK
# Procesando 57085/57525: SIOFF.OL
# Procesando 57086/57525: MILK.CN
# Procesando 57087/57525: KOPI.JK
# Procesando 57088/57525: BROGW
# Procesando 57089/57525: REP.MC
# Procesando 57090/57525: EEENF
# Procesando 57091/57525: EPD
# Procesando 57092/57525: ECTM
# Procesando 57093/57525: BPCL.NS
# Procesando 57094/57525: EGY
# Procesando 57095/57525: SUBC.OL
# Procesando 57096/57525: CESDF
# Procesando 57097/57525: ERINQ
# Procesando 57098/57525: QREE
# Procesando 57099/57525: VPK.AS
# Procesando 57100/57525: ORL.TA
# Procesando 57101/57525: CNQ
# Procesando 57102/57525: GLOP-PC
# Procesando 57103/57525: SNMP
# Procesando 57104/57525: PAGP
# Procesando 57105/57525: CVN.AX
# Procesando 57106/57525: SOUC.L
# Procesando 57107/57525: FRU.TO
# Procesando 57108/57525: 5017.T
# Procesando 57109/57525: 603906.SS
# Procesando 57110/57525: 002960.KS
# Procesando 57111/57525: TRMD-A.CO
# Procesando 57112/57525: SHLLF
# Procesando 57113/57525: TOP-R.BK
# Procesando 57114/57525: 600617.SS
# Procesando 57115/57525: MRGE
# Procesando 57116/57525: NGL-PC
# Procesando 57117/57525: SPRC.BK
# Procesando 57118/57525: AKSO.OL
# Procesando 57119/57525: VEN.AX
# Procesando 57120/57525: CSAN
# Procesando 57121/57525: NRZ.AX
# Procesando 57122/57525: ET-PE
# Procesando 57123/57525: 9528.SR
# Procesando 57124/57525: RNGR
# Procesando 57125/57525: LQZ.F
# Procesando 57126/57525: FPPP
# Procesando 57127/57525: SSLZY
# Procesando 57128/57525: OIL.CN
# Procesando 57129/57525: HINDPETRO.NS
# Procesando 57130/57525: FAR.AX
# Procesando 57131/57525: MGUY
# Procesando 57132/57525: SHEL
# Procesando 57133/57525: BPE5.DE
# Procesando 57134/57525: SHASF
# Procesando 57135/57525: TPIG.F
# Procesando 57136/57525: PETR4.SA
# Procesando 57137/57525: HINDPETRO.BO
# Procesando 57138/57525: BP.L
# Procesando 57139/57525: TOP.BK
# Procesando 57140/57525: CHTEX.BR
# Procesando 57141/57525: PTX.TA
# Procesando 57142/57525: NTOG.L
# Procesando 57143/57525: AKTAF
# Procesando 57144/57525: GXRFF
# Procesando 57145/57525: PMT.TO
# Procesando 57146/57525: NBR
# Procesando 57147/57525: 002828.SZ
# Procesando 57148/57525: CSTPF
# Procesando 57149/57525: 600871.SS
# Procesando 57150/57525: GLV.AX
# Procesando 57151/57525: VIVK
# Procesando 57152/57525: DEC.L
# Procesando 57153/57525: IPRC
# Procesando 57154/57525: SHLF.OL
# Procesando 57155/57525: UKOG.L
# Procesando 57156/57525: SBR
# Procesando 57157/57525: SNV.V
# Procesando 57158/57525: WCE.V
# Procesando 57159/57525: SPOWF
# Procesando 57160/57525: IGESF
# Procesando 57161/57525: KIST.L
# Procesando 57162/57525: AKRBP.OL
# Procesando 57163/57525: 2012.HK
# Procesando 57164/57525: MEN.L
# Procesando 57165/57525: JPR.AX
# Procesando 57166/57525: DR0.DE
# Procesando 57167/57525: YGR.TO
# Procesando 57168/57525: KELTF
# Procesando 57169/57525: CNE.L
# Procesando 57170/57525: ENOG.TA
# Procesando 57171/57525: HBR.L
# Procesando 57172/57525: BSHPF
# Procesando 57173/57525: BATL
# Procesando 57174/57525: TLW.L
# Procesando 57175/57525: PHAR.L
# Procesando 57176/57525: CHKR
# Procesando 57177/57525: OILCF
# Procesando 57178/57525: KWTEF
# Procesando 57179/57525: PRPRF
# Procesando 57180/57525: AST.L
# Procesando 57181/57525: DBRM
# Procesando 57182/57525: KGEI
# Procesando 57183/57525: ARX.TO
# Procesando 57184/57525: UJO.L
# Procesando 57185/57525: VAR.OL
# Procesando 57186/57525: BYE.AX
# Procesando 57187/57525: OIL.NS
# Procesando 57188/57525: CRT
# Procesando 57189/57525: EFIR
# Procesando 57190/57525: TCF.CN
# Procesando 57191/57525: CRNCY
# Procesando 57192/57525: ENOG.L
# Procesando 57193/57525: CE1.AX
# Procesando 57194/57525: EFVIF
# Procesando 57195/57525: TUWOY
# Procesando 57196/57525: SHPNF
# Procesando 57197/57525: WTE.L
# Procesando 57198/57525: RKOS
# Procesando 57199/57525: MMEX
# Procesando 57200/57525: PGNYF
# Procesando 57201/57525: 0N08.L
# Procesando 57202/57525: REN.JO
# Procesando 57203/57525: CIMEF
# Procesando 57204/57525: DDRIL.OL
# Procesando 57205/57525: 0LE3.L
# Procesando 57206/57525: PRS.OL
# Procesando 57207/57525: 603321.SS
# Procesando 57208/57525: 603318.SS
# Procesando 57209/57525: 1080.HK
# Procesando 57210/57525: 0HRZ.L
# Procesando 57211/57525: SOUTHWEST.NS
# Procesando 57212/57525: 0VCO.L
# Procesando 57213/57525: 0KTI.L
# Procesando 57214/57525: 0R7T.L
# Procesando 57215/57525: 0HRR.L
# Procesando 57216/57525: 7228.KL
# Procesando 57217/57525: 8239.HK
# Procesando 57218/57525: 001239.SZ
# Procesando 57219/57525: 68V.DE
# Procesando 57220/57525: 3303.HK
# Procesando 57221/57525: 0J0P.L
# Procesando 57222/57525: LMND
# Procesando 57223/57525: MXHN.DE
# Procesando 57224/57525: KIRLOSBROS.BO
# Procesando 57225/57525: AP
# Procesando 57226/57525: WINDMACHIN.BO
# Procesando 57227/57525: 605123.SS
# Procesando 57228/57525: 301022.SZ
# Procesando 57229/57525: 103140.KS
# Procesando 57230/57525: 3376.TW
# Procesando 57231/57525: HIHO
# Procesando 57232/57525: 300328.SZ
# Procesando 57233/57525: CI.ST
# Procesando 57234/57525: IVX.V
# Procesando 57235/57525: HONDAPOWER.NS
# Procesando 57236/57525: RCHN
# Procesando 57237/57525: 2535.HK
# Procesando 57238/57525: TKAMY
# Procesando 57239/57525: 1589.TW
# Procesando 57240/57525: 002645.SZ
# Procesando 57241/57525: 2039.HK
# Procesando 57242/57525: 2727.HK
# Procesando 57243/57525: GE
# Procesando 57244/57525: 603895.SS
# Procesando 57245/57525: 002816.SZ
# Procesando 57246/57525: PYR.TO
# Procesando 57247/57525: HWM-P
# Procesando 57248/57525: IIFL.NS
# Procesando 57249/57525: ROTO.BO
# Procesando 57250/57525: 1673.HK
# Procesando 57251/57525: GJ.CO
# Procesando 57252/57525: UHOIF
# Procesando 57253/57525: 000404.SZ
# Procesando 57254/57525: 0679.HK
# Procesando 57255/57525: 6339.T
# Procesando 57256/57525: 010040.KS
# Procesando 57257/57525: WRTBF
# Procesando 57258/57525: DUCON.BO
# Procesando 57259/57525: 6309.T
# Procesando 57260/57525: 000862.SZ
# Procesando 57261/57525: 8133.HK
# Procesando 57262/57525: 603917.SS
# Procesando 57263/57525: 9880.HK
# Procesando 57264/57525: DAR.DE
# Procesando 57265/57525: JPSWY
# Procesando 57266/57525: 6369.T
# Procesando 57267/57525: 002514.SZ
# Procesando 57268/57525: KNEBV.HE
# Procesando 57269/57525: 002531.SZ
# Procesando 57270/57525: 688499.SS
# Procesando 57271/57525: 300092.SZ
# Procesando 57272/57525: CETY
# Procesando 57273/57525: 688698.SS
# Procesando 57274/57525: DAIUF
# Procesando 57275/57525: 300307.SZ
# Procesando 57276/57525: 000837.SZ
# Procesando 57277/57525: DEA
# Procesando 57278/57525: 1637.HK
# Procesando 57279/57525: 6505.T
# Procesando 57280/57525: DANR.MI
# Procesando 57281/57525: BOMILL.ST
# Procesando 57282/57525: VALMT.HE
# Procesando 57283/57525: MARSHALL.NS
# Procesando 57284/57525: INEP3.SA
# Procesando 57285/57525: 085310.KS
# Procesando 57286/57525: 300990.SZ
# Procesando 57287/57525: DUCON.NS
# Procesando 57288/57525: UREKA.BK
# Procesando 57289/57525: JANUSCORP.BO
# Procesando 57290/57525: GGEO.ST
# Procesando 57291/57525: STW.ST
# Procesando 57292/57525: 688003.SS
# Procesando 57293/57525: NPWR
# Procesando 57294/57525: 002877.SZ
# Procesando 57295/57525: AHL.AX
# Procesando 57296/57525: 002438.SZ
# Procesando 57297/57525: 301199.SZ
# Procesando 57298/57525: 7414.T
# Procesando 57299/57525: MWA
# Procesando 57300/57525: RCSL4.SA
# Procesando 57301/57525: IWEL.BO
# Procesando 57302/57525: PEDU.SW
# Procesando 57303/57525: CMH.L
# Procesando 57304/57525: FLEXQ.ST
# Procesando 57305/57525: TDPOWERSYS.BO
# Procesando 57306/57525: 603277.SS
# Procesando 57307/57525: SHPW
# Procesando 57308/57525: 6250.T
# Procesando 57309/57525: TPLKF
# Procesando 57310/57525: VACNY
# Procesando 57311/57525: SHOM.TA
# Procesando 57312/57525: HERCULES.BO
# Procesando 57313/57525: TPE.DE
# Procesando 57314/57525: 2476.TW
# Procesando 57315/57525: RRX
# Procesando 57316/57525: DELTAMAGNT.NS
# Procesando 57317/57525: GF.SW
# Procesando 57318/57525: 3167.TW
# Procesando 57319/57525: 6279.T
# Procesando 57320/57525: PMN.SW
# Procesando 57321/57525: TRF.BO
# Procesando 57322/57525: 002266.SZ
# Procesando 57323/57525: OERL.SW
# Procesando 57324/57525: STRN.SW
# Procesando 57325/57525: ALIG.ST
# Procesando 57326/57525: 6346.T
# Procesando 57327/57525: IRB.BO
# Procesando 57328/57525: 603666.SS
# Procesando 57329/57525: IJ8.DE
# Procesando 57330/57525: SHI.L
# Procesando 57331/57525: NOIDATOLL.NS
# Procesando 57332/57525: RAA.DE
# Procesando 57333/57525: 300521.SZ
# Procesando 57334/57525: 112610.KS
# Procesando 57335/57525: 1052.HK
# Procesando 57336/57525: 7417.T
# Procesando 57337/57525: NXH.V
# Procesando 57338/57525: TEBE.JK
# Procesando 57339/57525: 688022.SS
# Procesando 57340/57525: 6203.T
# Procesando 57341/57525: MMH.NZ
# Procesando 57342/57525: BEEP
# Procesando 57343/57525: ATAM.BO
# Procesando 57344/57525: SDIP-B.ST
# Procesando 57345/57525: 002469.SZ
# Procesando 57346/57525: 8077.T
# Procesando 57347/57525: GMRP&UI.NS
# Procesando 57348/57525: 3433.T
# Procesando 57349/57525: 0576.HK
# Procesando 57350/57525: 0697.HK
# Procesando 57351/57525: 300757.SZ
# Procesando 57352/57525: SOHO.L
# Procesando 57353/57525: 600020.SS
# Procesando 57354/57525: NOIDATOLL.BO
# Procesando 57355/57525: 6205.T
# Procesando 57356/57525: VWS.CO
# Procesando 57357/57525: BRCK.L
# Procesando 57358/57525: KUAS.JK
# Procesando 57359/57525: 600605.SS
# Procesando 57360/57525: FERG.L
# Procesando 57361/57525: 603320.SS
# Procesando 57362/57525: ARTR
# Procesando 57363/57525: 0HAL.L
# Procesando 57364/57525: 0J76.L
# Procesando 57365/57525: KIRLPNU.NS
# Procesando 57366/57525: ALNSC.PA
# Procesando 57367/57525: BURU
# Procesando 57368/57525: LPPI
# Procesando 57369/57525: 603698.SS
# Procesando 57370/57525: 000786.SZ
# Procesando 57371/57525: 0QKA.L
# Procesando 57372/57525: 0Q4C.L
# Procesando 57373/57525: CHMI
# Procesando 57374/57525: VRS.AX
# Procesando 57375/57525: NCTKF
# Procesando 57376/57525: 002883.SZ
# Procesando 57377/57525: 002116.SZ
# Procesando 57378/57525: TOTO.JK
# Procesando 57379/57525: 1934.T
# Procesando 57380/57525: 0J46.L
# Procesando 57381/57525: 300606.SZ
# Procesando 57382/57525: BEARDSELL.BO
# Procesando 57383/57525: AFIIQ
# Procesando 57384/57525: 603357.SS
# Procesando 57385/57525: DRT.BK
# Procesando 57386/57525: MADHAV.NS
# Procesando 57387/57525: JSGRY
# Procesando 57388/57525: PPIH
# Procesando 57389/57525: JBI
# Procesando 57390/57525: AGGU.L
# Procesando 57391/57525: 1897.HK
# Procesando 57392/57525: 9531.SR
# Procesando 57393/57525: 301010.SZ
# Procesando 57394/57525: LYL.AX
# Procesando 57395/57525: 6865.HK
# Procesando 57396/57525: GBERY
# Procesando 57397/57525: 000215.KS
# Procesando 57398/57525: BRIH.TA
# Procesando 57399/57525: 108670.KS
# Procesando 57400/57525: 3313.HK
# Procesando 57401/57525: 300093.SZ
# Procesando 57402/57525: 600212.SS
# Procesando 57403/57525: 8466.TW
# Procesando 57404/57525: 1887.T
# Procesando 57405/57525: TIJARIA.NS
# Procesando 57406/57525: TREX
# Procesando 57407/57525: POLY.ST
# Procesando 57408/57525: SEJALLTD.NS
# Procesando 57409/57525: 601865.SS
# Procesando 57410/57525: AFK.OL
# Procesando 57411/57525: 600202.SS
# Procesando 57412/57525: HAGA4.SA
# Procesando 57413/57525: 24CS.BK
# Procesando 57414/57525: 9913.HK
# Procesando 57415/57525: IGTI3.SA
# Procesando 57416/57525: 0G67.L
# Procesando 57417/57525: 9934.TW
# Procesando 57418/57525: BJC.BK
# Procesando 57419/57525: ZHUD
# Procesando 57420/57525: EMB.AX
# Procesando 57421/57525: 002480.SZ
# Procesando 57422/57525: APOLLOPIPE.NS
# Procesando 57423/57525: MBLINFRA.BO
# Procesando 57424/57525: 1806.TW
# Procesando 57425/57525: 0132.HK
# Procesando 57426/57525: 1980.T
# Procesando 57427/57525: IKAI.JK
# Procesando 57428/57525: 0041.KL
# Procesando 57429/57525: 052690.KS
# Procesando 57430/57525: F9D.SI
# Procesando 57431/57525: 8285.T
# Procesando 57432/57525: 0087.HK
# Procesando 57433/57525: MNTX
# Procesando 57434/57525: LAMR
# Procesando 57435/57525: VCISF
# Procesando 57436/57525: BFLBY
# Procesando 57437/57525: 000725.KS
# Procesando 57438/57525: WLDN
# Procesando 57439/57525: 000923.SZ
# Procesando 57440/57525: 601390.SS
# Procesando 57441/57525: 1372.HK
# Procesando 57442/57525: IGRD.QA
# Procesando 57443/57525: 603017.SS
# Procesando 57444/57525: 1802.HK
# Procesando 57445/57525: KIM-PL
# Procesando 57446/57525: 8523.HK
# Procesando 57447/57525: ACF.AX
# Procesando 57448/57525: 4642.T
# Procesando 57449/57525: 1963.T
# Procesando 57450/57525: MGNS.L
# Procesando 57451/57525: PXM.WA
# Procesando 57452/57525: RIOCF
# Procesando 57453/57525: 300818.SZ
# Procesando 57454/57525: FBYD
# Procesando 57455/57525: CMCT
# Procesando 57456/57525: 603098.SS
# Procesando 57457/57525: FBR.AX
# Procesando 57458/57525: SITOWS.HE
# Procesando 57459/57525: 2404.TW
# Procesando 57460/57525: MRB.WA
# Procesando 57461/57525: EPIAF
# Procesando 57462/57525: 5227.KL
# Procesando 57463/57525: JISLJALEQS.BO
# Procesando 57464/57525: HEIJM.AS
# Procesando 57465/57525: TS0U.SI
# Procesando 57466/57525: BALMLAWRIE.BO
# Procesando 57467/57525: RT.BK
# Procesando 57468/57525: FEE.WA
# Procesando 57469/57525: ELLAKTOR.AT
# Procesando 57470/57525: HOMI.BR
# Procesando 57471/57525: ETE.BK
# Procesando 57472/57525: JR.BK
# Procesando 57473/57525: PVP.NS
# Procesando 57474/57525: 601186.SS
# Procesando 57475/57525: 2515.TW
# Procesando 57476/57525: 300668.SZ
# Procesando 57477/57525: 1582.HK
# Procesando 57478/57525: GRINFRA.NS
# Procesando 57479/57525: KMMPF
# Procesando 57480/57525: 000906.SZ
# Procesando 57481/57525: VESTUM.ST
# Procesando 57482/57525: MTSA4.SA
# Procesando 57483/57525: 601868.SS
# Procesando 57484/57525: ELTEL.ST
# Procesando 57485/57525: MANG.JK
# Procesando 57486/57525: GEPIL.BO
# Procesando 57487/57525: SKA-B.ST
# Procesando 57488/57525: SUPREMEINF.BO
# Procesando 57489/57525: 8305.HK
# Procesando 57490/57525: TPOLY.BK
# Procesando 57491/57525: 0924.HK
# Procesando 57492/57525: TPHQ.NS
# Procesando 57493/57525: 004960.KS
# Procesando 57494/57525: 8059.HK
# Procesando 57495/57525: MR7.SI
# Procesando 57496/57525: NEXS.L
# Procesando 57497/57525: ITB.WA
# Procesando 57498/57525: 603717.SS
# Procesando 57499/57525: 2236.HK
# Procesando 57500/57525: WSPOF
# Procesando 57501/57525: 1810.T
# Procesando 57502/57525: TNDT.BK
# Procesando 57503/57525: 3OY1.SG
# Procesando 57504/57525: OHLA.MC
# Procesando 57505/57525: 002310.SZ
# Procesando 57506/57525: SBC.NS
# Procesando 57507/57525: 603778.SS
# Procesando 57508/57525: CIVIL.BK
# Procesando 57509/57525: 002822.SZ
# Procesando 57510/57525: 1866.T
# Procesando 57511/57525: 2663.HK
# Procesando 57512/57525: AMRC
# Procesando 57513/57525: FG.ST
# Procesando 57514/57525: TRITN.BK
# Procesando 57515/57525: SADBHIN.BO
# Procesando 57516/57525: NORCO.OL
# Procesando 57517/57525: 300746.SZ
# Procesando 57518/57525: 9906.TW
# Procesando 57519/57525: TPHQ.BO
# Procesando 57520/57525: 003001.SZ
# Procesando 57521/57525: 3OY1.F
# Procesando 57522/57525: 1762.T
# Procesando 57523/57525: BLD
# Procesando 57524/57525: 1727.HK
# Procesando 57525/57525: 300621.SZ
#     symbol                                 name    price  \
# 0    NDBKY                Nedbank Group Limited  11.4900
# 1    NRRWF                  Nuran Wireless Inc.   0.0909
# 2  5309.KL                  ITMAX System Berhad   2.1900
# 3    TQGEX  T. Rowe Price QM Global Equity Fund  16.7800
# 4   MEA.AX                      McGrath Limited   0.5950
#
#                          exchange exchangeShortName  \
# 0                       Other OTC               PNK
# 1                       Other OTC               PNK
# 2                    Kuala Lumpur               KLS
# 3                          NASDAQ            NASDAQ
# 4  Australian Securities Exchange               ASX
#
#                          Industry Profit Margins       PE Ratio  \
# 0                Banks - Regional        0.25108       6.921687
# 1         Communication Equipment  No disponible  No disponible
# 2  Security & Protection Services        0.42276           36.5
# 3         Industria no disponible  No disponible  No disponible
# 4            Real Estate Services        0.14849            8.5
#
#               Country Full Time Employees                  City
# 0        South Africa       No disponible               Sandton
# 1              Canada       No disponible             Vancouver
# 2            Malaysia       No disponible          Kuala Lumpur
# 3  País no disponible       No disponible  Ciudad no disponible
# 4           Australia                 243               Pyrmont

# %% [markdown]
# ## General analysis of the distribution of records, fields, and individual values of each column
# - Likewise, we want to verify that regardless of whether the extraction is done directly or saved and then extracted as a CSV file, the data remains the same.
# - However, it is evident that in this case, as it was a direct extraction, this EDA works with a larger number of data points since in the other EDA, the saving of records to CSV was limited by the sheer volume of records.

# %%
df_final.head()
# Out:
#     symbol                                 name    price  \
# 0    NDBKY                Nedbank Group Limited  11.4900
# 1    NRRWF                  Nuran Wireless Inc.   0.0909
# 2  5309.KL                  ITMAX System Berhad   2.1900
# 3    TQGEX  T. Rowe Price QM Global Equity Fund  16.7800
# 4   MEA.AX                      McGrath Limited   0.5950
#
#                          exchange exchangeShortName  \
# 0                       Other OTC               PNK
# 1                       Other OTC               PNK
# 2                    Kuala Lumpur               KLS
# 3                          NASDAQ            NASDAQ
# 4  Australian Securities Exchange               ASX
#
#                          Industry Profit Margins       PE Ratio  \
# 0                Banks - Regional        0.25108       6.921687
# 1         Communication Equipment  No disponible  No disponible
# 2  Security & Protection Services        0.42276           36.5
# 3         Industria no disponible  No disponible  No disponible
# 4            Real Estate Services        0.14849            8.5
#
#               Country Full Time Employees                  City
# 0        South Africa       No disponible               Sandton
# 1              Canada       No disponible             Vancouver
# 2            Malaysia       No disponible          Kuala Lumpur
# 3  País no disponible       No disponible  Ciudad no disponible
# 4           Australia                 243               Pyrmont

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57525 entries, 0 to 57524
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symbol               57525 non-null  object
#  1   name                 57505 non-null  object
#  2   price                57525 non-null  float64
#  3   exchange             57517 non-null  object
#  4   exchangeShortName    57523 non-null  object
#  5   Industry             57525 non-null  object
#  6   Profit Margins       57525 non-null  object
#  7   PE Ratio             57525 non-null  object
#  8   Country              57525 non-null  object
#  9   Full Time Employees  57525 non-null  object
#  10  City                 57525 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 4.8+ MB

# %% [markdown]
# ## Removal of Records with "Not Available" Value in the Dataset
# - We decided to perform a rigorous cleaning process in which any record containing "Not Available" in any of its fields would be deleted, whether accompanied by other words or with "Not" in lowercase.
# - To facilitate the removal of cases where the "Not Available" fields started with a capital letter due to a complement or a character from the previous one, we decided to convert all strings in the dataframe to lowercase.
# - Fields with the aforementioned characteristics are replaced with NaN values to later remove them completely, finally resetting the index after removing the rows.

# %%
df_final = df_final.applymap(lambda x: x.lower() if isinstance(x, str) else x)

df_final.replace(to_replace=r'.*no\s+disponible.*', value=np.nan, regex=True, inplace=True)

df_final.dropna(inplace=True)

df_final.reset_index(drop=True, inplace=True)

print("Después de eliminar los registros 'No disponible':", df_final.shape)
# Out:
# Después de eliminar los registros 'No disponible': (17928, 11)
# C:\Users\fedeg\AppData\Local\Temp\ipykernel_18264\2513168915.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_final = df_final.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %% [markdown]
# ## Changing the Data Type of the 'Profit Margins', 'PE Ratio', and 'Full Time Employees' Columns to Numeric for Consistency in Handling Numbers Throughout the Records

# %%
df_final['profit margins'] = pd.to_numeric(df_final['profit margins'], errors='coerce')

df_final['pe ratio'] = pd.to_numeric(df_final['pe ratio'], errors='coerce')

df_final['full time employees'] = pd.to_numeric(df_final['full time employees'], errors='coerce')

# %% [markdown]
# ## Text Normalization in Fields and Records
# - As we can see, up to this point, we were handling our fields and records in a structure inconsistently, with some fields and records entirely in lowercase and others starting with uppercase letters.
# - We perform this normalization to maintain consistency and ease of manipulation among fields in our dataset, similarly, we do it as a best practice.

# %%
column_names = df_final.columns

new_column_names = {col: col.lower() if col[0].isupper() else col for col in column_names}

df_final = df_final.rename(columns=new_column_names)

print(df_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17928 entries, 0 to 17927
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symbol               17928 non-null  object
#  1   name                 17928 non-null  object
#  2   price                17928 non-null  float64
#  3   exchange             17928 non-null  object
#  4   exchangeShortName    17928 non-null  object
#  5   industry             17928 non-null  object
#  6   profit margins       17928 non-null  float64
#  7   pe ratio             17928 non-null  float64
#  8   country              17928 non-null  object
#  9   full time employees  17928 non-null  float64
#  10  city                 17928 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.5+ MB
# None

# %% [markdown]
# - Text normalization of records initially containing uppercase letters in our dataset.

# %%
df_final['industry'] = df_final['industry'].str.lower()

df_final['country'] = df_final['country'].str.lower()

df_final['city'] = df_final['city'].str.lower()

print(df_final.head())
# Out:
#       symbol                               name   price  \
# 0     mea.ax                    mcgrath limited   0.595
# 1     bnp.pa                     bnp paribas sa  63.860
# 2       ande                the andersons, inc.  56.760
# 3     vsl.nz               vulcan steel limited   8.950
# 4  002732.sz  guangdong yantang dairy co., ltd.  16.660
#
#                          exchange exchangeShortName              industry  \
# 0  australian securities exchange               asx  real estate services
# 1                           paris          euronext      banks - regional
# 2            nasdaq global select            nasdaq     food distribution
# 3                            nzse               nze                 steel
# 4                        shenzhen               shz        packaged foods
#
#    profit margins   pe ratio        country  full time employees       city
# 0         0.14849   8.500000      australia                243.0    pyrmont
# 1         0.25507  10.431373         france             183000.0      paris
# 2         0.00686  19.343536  united states               2259.0     maumee
# 3         0.05095  19.456520    new zealand               1283.0   auckland
# 4         0.09252  14.486957          china               1660.0  guangzhou

# %% [markdown]
# ## Verification of duplicate values present in our dataset
# - The result does not print any fields with duplicate values, confirming the absence of duplicate values in our dataset.

# %%
duplicates = df_final.duplicated()

duplicate_rows = df_final[duplicates]
print("Duplicate Values:")
print(duplicate_rows)
# Out:
# Duplicate Values:
# Empty DataFrame
# Columns: [symbol, name, price, exchange, exchangeShortName, industry, profit margins, pe ratio, country, full time employees, city]
# Index: []

# %% [markdown]
# ## Distribution of companies by country within the dataset
# - In this case, we obtained a dataset with a distribution of companies divided among four countries: China, the United States, India, and Japan, whereas in our project dataset, the trend was predominantly from the United States by a significant margin.
# - Although there is a trend of four countries in this dataset, we can observe how these four countries represent markets with different sectors and approaches that each country has in its own market.
# - At first glance with this graph, we can see several countries belonging to the same continent, Asia.

# %%
companies_per_country = df_final['country'].value_counts().head(10)  

plt.figure(figsize=(10, 6))

companies_per_country.plot(kind='pie', autopct='%1.1f%%', startangle=140)

plt.title('Distribution of Companies by Country')

plt.ylabel('')

plt.show()

# %% [markdown]
# ## Distribution of industry types within the dataset
# - The industry with the highest presence in our dataset is "banks-regional," referring to the inclusion of several regional bank companies from each region that offer their banking services not nationally or internationally but regionally.
# - Although there is no marked trend of a specific industry, the "banks-regional" industry does have a significantly high number of records to visually stand out compared to the second-ranked "specialty industrial machinery" ("banks-regional" with an 18.9% appearance within the dataset and "specialty industrial machinery" with a 13.7%), representing a difference of 5.2% between the first and second positions.

# %%
companies_per_industry = df_final['industry'].value_counts().head(10)  # Select only the top 10 most common industries

plt.figure(figsize=(10, 6))

companies_per_industry.plot(kind='bar')

plt.title('Top 10 Most Common Industries')

plt.xlabel('Industry')

plt.ylabel('Number of Companies')

plt.xticks(rotation=45, ha='right')

plt.show()

# %%
companies_per_industry = df_final['industry'].value_counts().head(10)

plt.figure(figsize=(8, 8))

companies_per_industry.plot(kind='pie', autopct='%1.1f%%', startangle=140)

plt.title('Top 10 Most Common Industries')

plt.show()

# %% [markdown]
# ## Industries with less presence within the dataset
# - In this graph, we find several industries referring to subcategories within the real estate sector, representing specific sectors within the investment real estate market, each with its particular focus on the type of property and associated business operations.
# - The subcategories we are referring to are as follows: "REIT-Office," "REIT-Specialty," "REIT-Healthcare Facilities," and "REIT-HOTEL-MOTEL."

# %%
less_common_companies_by_industry = df_final['industry'].value_counts().tail(10)

plt.figure(figsize=(10, 6))

less_common_companies_by_industry.plot(kind='bar')

plt.title('Top 10 Least Common Industries')

plt.xlabel('Industry')

plt.ylabel('Number of Companies')

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# ## Industries with the highest average profit margin within the dataset
# - We see how the "entertainment" industry has the highest profit margin in our dataset, indicating that on average, companies in this industry tend to have higher profit margins compared to other industries in our dataset.
# - Thanks to the pie chart displayed in percentages, we can see that 58.3% of the profit margin of all industries in our dataset is captured by only one industry, "entertainment."
# - Following the "entertainment" industry, we have the "medical instruments and supplies" industry with 11.6% and the gasoline industry with 7.3%.

# %%
df_final['profit margins'] = pd.to_numeric(df_final['profit margins'], errors='coerce')

average_profit_margin_per_industry = df_final.groupby('industry')['profit margins'].mean().sort_values(ascending=False)

top_industries = average_profit_margin_per_industry.head(10)

plt.figure(figsize=(10, 6))

top_industries.plot(kind='bar')

plt.title('Top 10 Industries with Highest Average Profit Margin')

plt.xlabel('Industry')

plt.ylabel('Average Profit Margin')

plt.xticks(rotation=45, ha='right')

plt.show()

# %%
df_final['profit margins'] = pd.to_numeric(df_final['profit margins'], errors='coerce')

average_profit_margin_per_industry = df_final.groupby('industry')['profit margins'].mean().sort_values(ascending=False)

top_industries = average_profit_margin_per_industry.head(10)

plt.figure(figsize=(8, 8))

top_industries.plot(kind='pie', autopct='%1.1f%%', startangle=140)

plt.title('Top 10 Industries with Highest Average Profit Margin')
plt.show()

# %% [markdown]
# ## Number of full-time employees by country
# - We see how the "United States" takes the top spot as the country with the most full-time employees, with a percentage difference of 13.4% over the second country with the most employees, which is "China."
# - It's not surprising to find these countries at the top, as both the "United States" and "China" represent giant economies, each handling a variety of international businesses and commerce.
# - We have "Japan" as the third country with the most full-time employees, which aligns with what several news sources and anime depict regarding the long working hours to which the Japanese population is exposed.

# %%
df_final['full time employees'] = pd.to_numeric(df_final['full time employees'], errors='coerce')

employees_per_country = df_final.groupby('country')['full time employees'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))

employees_per_country.plot(kind='bar')

plt.title('Number of Full-Time Employees by Country (Top 10)')

plt.xlabel('Country')

plt.ylabel('Number of Full-Time Employees')

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df_final['full time employees'] = pd.to_numeric(df_final['full time employees'], errors='coerce')

employees_per_country = df_final.groupby('country')['full time employees'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))

employees_per_country.plot(kind='pie', autopct='%1.1f%%', startangle=140)

plt.title('Percentage of Full-Time Employees by Country (Top 10)')

plt.show()

# %% [markdown]
# ## Percentage of full-time employees by industry
# - We have industries that we've seen before as the ones with the most records in our dataset, referring to the industries with the most companies in this dataset.
# - These industries are "banks-regional" and "specialty industrial machinery."
# - It's interesting to note that the industry with the highest percentage of full-time employees per industry is "banks-diversified," likely due to its wide range of services offered to a large number of clients, requiring full-time transactions and operations. This could also explain the presence of the "banks-regional" industry, as the services provided by both are essential for a 24-hour economy and society.

# %%
df_final['full time employees'] = pd.to_numeric(df_final['full time employees'], errors='coerce')

employees_per_industry = df_final.groupby('industry')['full time employees'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))

employees_per_industry.plot(kind='pie', autopct='%1.1f%%', startangle=140)

plt.title('Percentage of Full-Time Employees by Industry (Top 10)')

plt.show()

# %% [markdown]
# ## General overview of the distribution of full-time employees by industry
# - This graph provides a more comprehensive view of the distribution of full-time employees by industry.
# - From this graph, we can observe that besides banking services, the technology and entertainment sectors also maintain a high volume of employees. This is likely due to the nature of the services they offer, which are essential and widely used in daily life by the population.

# %%
top_30_industries = df_final['industry'].value_counts().head(30).index

data_filtered_top_30 = df_final[df_final['industry'].isin(top_30_industries)]

data_filtered_top_30['full time employees'] = pd.to_numeric(data_filtered_top_30['full time employees'], errors='coerce')

employees_per_industry = data_filtered_top_30.groupby('industry')['full time employees'].sum()

plt.figure(figsize=(12, 6))

employees_per_industry.plot(kind='bar')

plt.title('Distribution of Full-Time Employees by Industry (Top 30)')

plt.xlabel('Industry')

plt.ylabel('Number of Full-Time Employees')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\fedeg\AppData\Local\Temp\ipykernel_18264\1524486162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered_top_30['full time employees'] = pd.to_numeric(data_filtered_top_30['full time employees'], errors='coerce')
